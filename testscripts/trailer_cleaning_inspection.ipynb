# %%
import pandas as pd
import requests
import json
import csv
import time
import datetime
import re
import string
import gzip
import os

import numpy as np
import pickle #for saving output files, pickles

def datetime_to_unix_time(d):
    return int(time.mktime(datetime.datetime.strptime(d, "%m/%d/%Y").timetuple()))

# %% [markdown]
# ## Import trailers from my pickle file!

# %%
with open('/home/russell/Documents/DataScience/DonorsChoose/Data/trailers.pickle', 'rb') as handle:
    trailers = pickle.load(handle)

# %% [markdown]
# ## Process trailers from DonorsChoose create data files

# %%
data = pd.DataFrame(trailers.items(), columns=['id', 'trailer'])

# %%
data.columns = ['id','text']
pd.set_option('max_colwidth', 400)
data.head()
# Out:
#         id  \
# 0  4956615
# 1  4904116
# 2  4333875
# 3  4948217
# 4  4946464
#
#                                                                                                                                                          text
# 0                                                               Help me give my students a summer reading boost with a very engaging digital reading program.
# 1              Help me give my students various dice and a starting dice game to use in endless ways at home to practice, reinforce, and learn math concepts.
# 2                                     Help me give my students a safe, welcoming, comfortable classroom space where they can feel at home and ready to learn!
# 3             Help me give my students basic school supplies!  Every child needs a pencil and now even disinfectant wipes to keep everyone safe and learning!
# 4  Help me give my students the hands on materials they need during Remote learning! I have included hands on materials as well as a math workbook and snack.

# %% [markdown]
# ### Clean up text

# %%
# not using re.sub(r'[^a-zA-Z\s]', '', t) to avoid losing emojis
text = [re.sub(r'([0-9]+?)', ' ', t).lower() for t in data['text']] # remove all numbers and symbols
text = [re.sub(r'(!|"|#|\$|%|&|\'|\(|\)|\*|\+|,|-|\.|/|:|;|<|=|>|\?|@|\[|\\|\]|\^|_|`|{|\||}|~)+', ' ', t) for t in text]
data['text'] = [re.sub(r'\s+\s', ' ', t).strip() for t in text] # repace double spaces with single spaces

data = data.loc[data['text'].map(len) > 5].reset_index(drop = True) # keep only strings longer than 5 characters

# %% [markdown]
# # Discovering and Visualizing Topics in Texts

# %% [markdown]
# Most typical cases of text classification in NLP (named entity recognition, question answering, etc) require training datasets where each piece of text is associted with a label. However, in real-life scenarios, text collections rarely come with metadata labels that tell you what the texts are about. When people answer open-ended survey questions, for example, they don't repeat detectable keywords in their answer with the topics they discuss.

# %% [markdown]
# **Topic modeling** is an unsupervised classification technique that is able to discover the topics in a collection of texts by looking at their commonalities. In this context, "topics" refers to groups of related words that often occur together in the same text. For example, in a collection of newspaper articles a topic model may identify one topic that is made up of words such as "politician", "law", and "parliament", and another characterized by words such as "player", "match" and "penalty". Topic models only go as far as identifying clusters of related words; a human is still needed to interpret these clusters and give them labels such as "politics" and "football".
#
# One of the most popular topic models is Latent Dirichlet Allocation (LDA). LDA is a generative model that sees every text as a mixture of topics and each sentence as a mixture of words. For example, the "football" topic will generate the word "penalty" with a high probability, while the "politics" topic will have a much higher probability for "politician" than for "penalty". Other words, such as "the" and "an", will have similar probabilities in all topics. LDA takes its name from the Dirichlet probability distribution. This is the prior distribution it assumes the topics in a text will have.
#
# Modified from https://github.com/nlptown/nlp-notebooks/blob/master/Discovering%20and%20Visualizing%20Topics%20in%20Texts%20with%20LDA.ipynb

# %% [markdown]
# ## Data

# %% [markdown]
# Insight fellows frequently come up with project ideas that revolve around topic modeling of online reviews. Here, we'll use a dataset of project 'trailers' from the website DonorsChoose providing a brief description of the reason/project for which a teacher is requesting funding.

# %%
data.head(2)
# Out:
#         id  \
# 0  4956615
# 1  4904116
#
#                                                                                                                                           text
# 0                                                 help me give my students a summer reading boost with a very engaging digital reading program
# 1  help me give my students various dice and a starting dice game to use in endless ways at home to practice reinforce and learn math concepts

# %% [markdown]
# ## Preprocessing
#
# Before we train a topic model, we need to tokenize our texts. Let's do this with the [spaCy](https://spacy.io/) NLP library. We need to load a statisti English and use spaCy to perform our first preprocessing pass:

# %%
import spacy

# If you haven't installed the spaCy language model, uncomment the following line and run this cell
# ! python -m spacy download en_core_web_sm

# You will need to restart the notebook (go to the menu Kernel -> Restart) and re-run cells up to this point

# %%
nlp = spacy.load('en_core_web_sm')

texts = data['text'].tolist()
# %time spacy_docs = list(nlp.pipe(texts))
# Out:
# CPU times: user 2.14 s, sys: 385 ms, total: 2.52 s
# Wall time: 2.53 s

# %% [markdown]
# The text of each review is now a spaCy Doc that we can transform into a list of tokens. Instead of the original tokens, we're going to work with the **lemmas** instead. This will allow our model to generalize and understand that different forms of a word should be treated as one.
#
# Stemming and Lemmatization both generate the root form of the words. Lemmatization uses the rules about a language and the resulting tokens are all actual words. For example, the word "thought" becomes the lemma "think". Stemming is a crude heuristic that chops off the ends of words such that the resulting tokens may not be actual words. Stemming is faster but only works well for simple words like "toys" and "toy".
#
# This is the full list of our initial preprocessing steps:
#
# - remove all words shorter than 2 characters (these are often fairly uninteresting from a topical point of view)
# - drop all stopwords
# - lowercase remaining lemmas

# %%
docs = [[t.lemma_.lower() for t in doc if len(t.orth_) > 2 and not t.is_stop] for doc in spacy_docs]
for i in range(5):
    print(docs[i])
    print('\n')
# Out:
# ['help', 'student', 'summer', 'reading', 'boost', 'engaging', 'digital', 'reading', 'program']
#
#
# ['help', 'student', 'dice', 'start', 'dice', 'game', 'use', 'endless', 'way', 'home', 'practice', 'reinforce', 'learn', 'math', 'concept']
#
#
# ['help', 'student', 'safe', 'welcoming', 'comfortable', 'classroom', 'space', 'feel', 'home', 'ready', 'learn']
#
#
# ['help', 'student', 'basic', 'school', 'supply', 'child', 'need', 'pencil', 'disinfectant', 'wipe', 'safe', 'learning']
#
#
# ['help', 'student', 'hand', 'material', 'need', 'remote', 'learning', 'include', 'hand', 'material', 'math', 'workbook', 'snack']

# %% [markdown]
# Next, we also want to take frequent bigrams into account. **Bigrams are multiword units**, such as "colored pencil" that actually form one word rather than two. We'll use Gensim to first identify the frequent bigrams in the corpus, then append them to the list of tokens for the documents in which they appear. This means the bigrams will not be in their correct position in the text, but that's fine: topic models are bag-of-word models that ignore word position anyway.

# %%
import re
from gensim.models import Phrases

bigram = Phrases(docs, min_count=10)
tokens = []

for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:  # bigrams can be recognized by the "_" that joins the invidual words
            docs[idx].append(token)
            tokens.append(token)
            
print(list(set(tokens))[:10])
# Out:
# ['high_interest', 'classroom_library', 'distance_learning', 'comic_strip', 'seating_option', 'flexible_seating', 'document_camera', 'dry_erase', 'social_emotional', 'school_year']

# %%
pickle_out = open('/home/russell/Documents/DataScience/DonorsChoose/Data/cleantrailer.pickle',"wb")
pickle.dump(docs, pickle_out)
pickle_out.close()

# %% [markdown]
# Next, we move on to the final Gensim-specific preprocessing steps. First, we create a dictionary representation of the documents. This dictionary will map each word to a unique ID and help us create bag-of-word representations of each document. These bag-of-word representations contain the ids of the words in the document, together with their frequency. Additionally, we can remove the least and most frequent words from the vocabulary. This improves the quality of our topic model and speeds up its training. The minimum frequency of a word is expressed as an absolute number, the maximum frequency is the proportion of documents a word is allowed to occur in.

# %%
from gensim.corpora import Dictionary

dictionary = Dictionary(docs)
print('Number of unique words in original documents:', len(dictionary))

dictionary.filter_extremes(no_below=3, no_above=0.25)
print('Number of unique words after removing rare and common words:', len(dictionary))

print("Example representation of document 3:", dictionary.doc2bow(docs[2]))
# Out:
# Number of unique words in original documents: 2035
# Number of unique words after removing rare and common words: 668
# Example representation of document 3: [(10, 1), (11, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1)]

# %% [markdown]
# Then we create bag-of-word representations for each document in the corpus:

# %%
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %% [markdown]
# ## Training
#
# Now it's time to train our topic model. We do this with the following parameters:
#
# - `corpus`: the bag-of-word representations of our documents
# - `id2token`: the mapping from indices to words
# - `num_topics`: the number of topics we want the model to identify
# - `chunksize`: the number of documents the model sees for every update
# - `passes`: the number of times we show the total corpus to the model during training
# - `random_state`: we use a seed to ensure reproducibility.
#
# On a corpus of this size, the training will typically about a minute.

# %%
from gensim.models import LdaModel

# %time model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=6, chunksize=500, passes=3, random_state=1)
# Out:
# CPU times: user 745 ms, sys: 0 ns, total: 745 ms
# Wall time: 748 ms

# %% [markdown]
# ## Results

# %% [markdown]
# Let's take a look at what the model has learnt. We do this by printing out the ten words that are most characteristic for each of the topics. Most topics show common words like "experience", "item" and "school" but it's hard to identify any other patterns in the data.

# %%
for (topic, words) in model.print_topics():
    print(topic+1, ":", words, '\n')
# Out:
# 1 : 0.043*"fun" + 0.039*"learn" + 0.031*"seating" + 0.030*"classroom" + 0.024*"play" + 0.021*"table" + 0.020*"environment" + 0.020*"increase" + 0.019*"emotional" + 0.019*"skill"
#
# 2 : 0.057*"learning" + 0.028*"pencil" + 0.028*"activity" + 0.023*"item" + 0.021*"summer" + 0.019*"material" + 0.018*"reading" + 0.017*"home" + 0.016*"experience" + 0.016*"classroom"
#
# 3 : 0.038*"book" + 0.031*"read" + 0.031*"lesson" + 0.024*"distance" + 0.023*"laptop" + 0.023*"hand" + 0.022*"tile" + 0.021*"set" + 0.020*"language" + 0.020*"provide"
#
# 4 : 0.066*"science" + 0.046*"material" + 0.044*"art" + 0.044*"opportunity" + 0.030*"book" + 0.030*"meet" + 0.024*"high" + 0.021*"class" + 0.021*"interest" + 0.020*"learn"
#
# 5 : 0.050*"learn" + 0.042*"supply" + 0.036*"book" + 0.036*"home" + 0.028*"teach" + 0.021*"life" + 0.021*"continue" + 0.019*"new" + 0.018*"like" + 0.017*"opportunity"
#
# 6 : 0.049*"school" + 0.043*"year" + 0.035*"opportunity" + 0.026*"supply" + 0.025*"day" + 0.023*"college" + 0.021*"need" + 0.021*"classroom" + 0.020*"time" + 0.020*"school_year"

# %% [markdown]
# Another way of inspecting the topics is by visualizing them. This can be done with the [pyLDAvis](https://github.com/bmabey/pyLDAvis) library. PyLDAvis will show us how popular the topics are in our corpus, how similar the topics are, and which are the most salient words for this topic. Note it's important to set `sort_topics=False` on the call to pyLDAvis. If you don't, it will order the topics differently than Gensim.

# %%
import pyLDAvis.gensim
import warnings

pyLDAvis.enable_notebook()
warnings.filterwarnings("ignore", category=DeprecationWarning) 

pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.195150 -0.216808       1        1  14.012761
# 1      0.069649 -0.091411       2        1  20.025768
# 2      0.181087 -0.040047       3        1  13.282053
# 3      0.085365  0.110357       4        1  14.436414
# 4      0.049062  0.029671       5        1  22.138309
# 5     -0.190012  0.208238       6        1  16.104691, topic_info=            Term        Freq       Total Category  logprob  loglift
# 256      science   72.000000   72.000000  Default  30.0000  30.0000
# 121          art   49.000000   49.000000  Default  29.0000  29.0000
# 263         year   53.000000   53.000000  Default  28.0000  28.0000
# 25      learning  121.000000  121.000000  Default  27.0000  27.0000
# 299  opportunity  125.000000  125.000000  Default  26.0000  26.0000
# ..           ...         ...         ...      ...      ...      ...
# 18     classroom   25.397882  102.721161   Topic6  -3.8630   0.4287
# 212      quality   12.357983   17.799217   Topic6  -4.5834   1.4612
# 133         read   15.312106   62.743313   Topic6  -4.3690   0.4157
# 91         video   11.809304   17.057625   Topic6  -4.6288   1.4583
# 156    education   12.516580   51.900291   Topic6  -4.5706   0.4038
#
# [319 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 75        5  0.927626  academic
# 175       2  0.528773    access
# 175       3  0.099145    access
# 175       4  0.198290    access
# 175       5  0.066097    access
# ...     ...       ...       ...
# 178       3  0.048069     world
# 178       5  0.624893     world
# 252       2  0.917451   writing
# 263       2  0.018532      year
# 263       6  0.963639      year
#
# [455 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3, 4, 5, 6])

# %% [markdown]
# Finally, let's inspect the topics the model recognizes in some of the individual documents. Here we see how LDA tends to assign a high probability to a low number of topics for each documents, which makes its results easily interpretable.

# %%
for (text, doc) in zip(texts[:20], docs[:20]):
    print(text)
    print('-'*10)
    print([(topic+1, prob) for (topic, prob) in model[dictionary.doc2bow(doc)] if prob > 0.3])
    print('\n')
# Out:
# help me give my students a summer reading boost with a very engaging digital reading program
# ----------
# [(2, 0.8947776)]
#
#
# help me give my students various dice and a starting dice game to use in endless ways at home to practice reinforce and learn math concepts
# ----------
# [(5, 0.9402185)]
#
#
# help me give my students a safe welcoming comfortable classroom space where they can feel at home and ready to learn
# ----------
# [(1, 0.5075563), (5, 0.40881738)]
#
#
# help me give my students basic school supplies every child needs a pencil and now even disinfectant wipes to keep everyone safe and learning
# ----------
# [(2, 0.39377218), (5, 0.43039736)]
#
#
# help me give my students the hands on materials they need during remote learning i have included hands on materials as well as a math workbook and snack
# ----------
# [(2, 0.9354828)]
#
#
# help me give my students a comfortable social distance reading corner with mobile seats and individual book bins
# ----------
# [(1, 0.31220227), (2, 0.62686527)]
#
#
# help me give my students summer skill workbooks and playing cards for math games to continue distance learning
# ----------
# [(2, 0.8212365)]
#
#
# i need one virtual get your teach on admission and a teacher planner
# ----------
# [(5, 0.8316354)]
#
#
# help me give my students these books which are on their wish list
# ----------
# [(5, 0.57948774)]
#
#
# help me give my students a new clean colorful rug to sit on
# ----------
# [(3, 0.36462286), (6, 0.30895323)]
#
#
# help me give my students basic supplies they can use at home for distance learning to complete daily assignments and continue curriculum
# ----------
# [(6, 0.3563237)]
#
#
# help me give my students four ipads to use during study hall hour the last period of the day ell scholars can definitely use duolingo to practice language inquisition
# ----------
# [(2, 0.5454136)]
#
#
# help me give my students additional alternative seating for my classroom these seats will allow my students to choose the seating options that work best for their learning
# ----------
# [(1, 0.6020774), (2, 0.3419587)]
#
#
# help me give my students the chance to improve their math skills using ixl an interactive site that can provide academic support at home during this challenging time
# ----------
# [(5, 0.80200046)]
#
#
# help me give my students healthy snacks to eat at home during this trying tough time while they are distance learning
# ----------
# [(2, 0.56374526)]
#
#
# help me give my students materials to build the rocket ship lamp these construction materials will help support our summer steam lessons after watching our video lessons students will design their own version to make at school
# ----------
# [(2, 0.30813822), (6, 0.311573)]
#
#
# help me give my students a brother color laser printer and replacement toner cartridges
# ----------
# [(3, 0.8610304)]
#
#
# help me give my students need ink and toner cartridges for our classroom printer
# ----------
# [(3, 0.64211005)]
#
#
# help me give my students make a difference and learn about themselves their cultures look hopefully to the future for all they can do and achieve
# ----------
# [(5, 0.8609482)]
#
#
# help me give my students a cabinet to store supplies manipulatives and materials
# ----------
# [(2, 0.5067284), (5, 0.35924113)]

# %%
docs
# Out:
# [['help',
#   'student',
#   'summer',
#   'reading',
#   'boost',
#   'engaging',
#   'digital',
#   'reading',
#   'program'],
#  ['help',
#   'student',
#   'dice',
#   'start',
#   'dice',
#   'game',
#   'use',
#   'endless',
#   'way',
#   'home',
#   'practice',
#   'reinforce',
#   'learn',
#   'math',
#   'concept'],
#  ['help',
#   'student',
#   'safe',
#   'welcoming',
#   'comfortable',
#   'classroom',
#   'space',
#   'feel',
#   'home',
#   'ready',
#   'learn'],
#  ['help',
#   'student',
#   'basic',
#   'school',
#   'supply',
#   'child',
#   'need',
#   'pencil',
#   'disinfectant',
#   'wipe',
#   'safe',
#   'learning'],
#  ['help',
#   'student',
#   'hand',
#   'material',
#   'need',
#   'remote',
#   'learning',
#   'include',
#   'hand',
#   'material',
#   'math',
#   'workbook',
#   'snack',
#   'remote_learning'],
#  ['help',
#   'student',
#   'comfortable',
#   'social',
#   'distance',
#   'reading',
#   'corner',
#   'mobile',
#   'seat',
#   'individual',
#   'book',
#   'bin'],
#  ['help',
#   'student',
#   'summer',
#   'skill',
#   'workbook',
#   'play',
#   'card',
#   'math',
#   'game',
#   'continue',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['need', 'virtual', 'teach', 'admission', 'teacher', 'planner'],
#  ['help', 'student', 'book', 'wish', 'list'],
#  ['help', 'student', 'new', 'clean', 'colorful', 'rug', 'sit'],
#  ['help',
#   'student',
#   'basic',
#   'supply',
#   'use',
#   'home',
#   'distance',
#   'learn',
#   'complete',
#   'daily',
#   'assignment',
#   'continue',
#   'curriculum'],
#  ['help',
#   'student',
#   'ipad',
#   'use',
#   'study',
#   'hall',
#   'hour',
#   'period',
#   'day',
#   'ell',
#   'scholar',
#   'definitely',
#   'use',
#   'duolingo',
#   'practice',
#   'language',
#   'inquisition'],
#  ['help',
#   'student',
#   'additional',
#   'alternative',
#   'seat',
#   'classroom',
#   'seat',
#   'allow',
#   'student',
#   'choose',
#   'seating',
#   'option',
#   'work',
#   'best',
#   'learning',
#   'seating_option'],
#  ['help',
#   'student',
#   'chance',
#   'improve',
#   'math',
#   'skill',
#   'ixl',
#   'interactive',
#   'site',
#   'provide',
#   'academic',
#   'support',
#   'home',
#   'challenge',
#   'time'],
#  ['help',
#   'student',
#   'healthy',
#   'snack',
#   'eat',
#   'home',
#   'try',
#   'tough',
#   'time',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help',
#   'student',
#   'material',
#   'build',
#   'rocket',
#   'ship',
#   'lamp',
#   'construction',
#   'material',
#   'help',
#   'support',
#   'summer',
#   'steam',
#   'lesson',
#   'watch',
#   'video',
#   'lesson',
#   'student',
#   'design',
#   'version',
#   'school'],
#  ['help',
#   'student',
#   'brother',
#   'color',
#   'laser',
#   'printer',
#   'replacement',
#   'toner',
#   'cartridge'],
#  ['help',
#   'student',
#   'need',
#   'ink',
#   'toner',
#   'cartridge',
#   'classroom',
#   'printer'],
#  ['help',
#   'student',
#   'difference',
#   'learn',
#   'culture',
#   'look',
#   'hopefully',
#   'future',
#   'achieve'],
#  ['help', 'student', 'cabinet', 'store', 'supply', 'manipulative', 'material'],
#  ['help',
#   'student',
#   'headphone',
#   'enhance',
#   'virtual',
#   'learning',
#   'environment',
#   'keep',
#   'focus',
#   'track'],
#  ['help', 'student', 'new', 'steam', 'carpet', 'space', 'start', 'lesson'],
#  ['help',
#   'student',
#   'colleague',
#   'book',
#   'represent',
#   'diverse',
#   'population',
#   'school',
#   'cultivate',
#   'empathy',
#   'human',
#   'love',
#   'literature'],
#  ['help',
#   'student',
#   'customized',
#   'class',
#   'aid',
#   'kit',
#   'mask',
#   'hand',
#   'sanitizer',
#   'college',
#   'fall'],
#  ['help',
#   'student',
#   'art',
#   'supply',
#   'paper',
#   'paint',
#   'color',
#   'art',
#   'stick',
#   'crayon',
#   'continue',
#   'create',
#   'art',
#   'home'],
#  ['help', 'student', 'soap', 'glove', 'lotion', 'hand', 'clean'],
#  ['help',
#   'student',
#   'chromebook',
#   'help',
#   'integrate',
#   'technology',
#   'everyday',
#   'class',
#   'activity',
#   'math',
#   'read',
#   'intervention',
#   'study',
#   'review',
#   'skill',
#   'complete',
#   'assignment',
#   'research',
#   'project'],
#  ['help', 'student', 'class', 'ipad', 'help', 'learn', 'remotely'],
#  ['help',
#   'student',
#   'yoga',
#   'mat',
#   'excite',
#   'student',
#   'encourage',
#   'try',
#   'yoga',
#   'way',
#   'stay',
#   'calm',
#   'focused',
#   'fit'],
#  ['help',
#   'student',
#   'osmo',
#   'code',
#   'jam',
#   'kit',
#   'osmo',
#   'genius',
#   'kit',
#   'item',
#   'allow',
#   'tap',
#   'creative'],
#  ['help', 'student', 'color', 'laser', 'printer', 'need', 'print', 'picture'],
#  ['help',
#   'student',
#   'book',
#   'social',
#   'justice',
#   'history',
#   'inspiration',
#   'today'],
#  ['help',
#   'student',
#   'physical',
#   'education',
#   'equipment',
#   'include',
#   'animal',
#   'shape',
#   'bean',
#   'bag',
#   'cone',
#   'yarn',
#   'ball',
#   'rubber',
#   'string',
#   'ball',
#   'help',
#   'develop',
#   'eye',
#   'hand',
#   'coordination',
#   'agility'],
#  ['help',
#   'student',
#   'basic',
#   'art',
#   'material',
#   'develop',
#   'creativity',
#   'early',
#   'literacy',
#   'skill'],
#  ['help',
#   'student',
#   'material',
#   'supply',
#   'need',
#   'continue',
#   'successful',
#   'learning',
#   'home'],
#  ['help',
#   'student',
#   'whiteboard',
#   'efficiently',
#   'effectively',
#   'display',
#   'sound',
#   'picture',
#   'spelling',
#   'reading',
#   'rule',
#   'model',
#   'write',
#   'coding',
#   'word',
#   'sentence'],
#  ['help',
#   'student',
#   'good',
#   'binder',
#   'use',
#   'algebra',
#   'pre',
#   'algebra',
#   'class',
#   'useful',
#   'teach',
#   'school'],
#  ['help', 'student', 'access', 'resource', 'distance', 'summer', 'learning'],
#  ['help',
#   'student',
#   'picture',
#   'book',
#   'biography',
#   'reflect',
#   'diverse',
#   'view',
#   'world'],
#  ['help',
#   'student',
#   'chance',
#   'brain',
#   'engage',
#   'learn',
#   'summer',
#   'brain',
#   'quest'],
#  ['help',
#   'student',
#   'table',
#   'music',
#   'stand',
#   'better',
#   'music',
#   'learn',
#   'play',
#   'instrument'],
#  ['help',
#   'student',
#   'book',
#   'set',
#   'fire',
#   'read',
#   'give',
#   'high',
#   'interest',
#   'area',
#   'graphic',
#   'novel',
#   'intersectionality',
#   'black',
#   'hero',
#   'puberty',
#   'high_interest'],
#  ['help',
#   'student',
#   'chromebook',
#   'access',
#   'engage',
#   'intervention',
#   'program',
#   'activity'],
#  ['help',
#   'student',
#   'resource',
#   'distance',
#   'learning',
#   'teacher',
#   'pay',
#   'teacher',
#   'resource',
#   'distance_learning'],
#  ['help',
#   'student',
#   'math',
#   'essential',
#   'supply',
#   'help',
#   'upcoming',
#   'math',
#   'lesson'],
#  ['help',
#   'student',
#   'engage',
#   'listening',
#   'center',
#   'able',
#   'independently',
#   'listen',
#   'text',
#   'love'],
#  ['help', 'student', 'computer', 'order', 'research', 'topic', 'important'],
#  ['help',
#   'student',
#   'tool',
#   'allow',
#   'good',
#   'quality',
#   'digital',
#   'recording',
#   'video',
#   'conferencing',
#   'provide',
#   'camcorder',
#   'large',
#   'screen',
#   'monitor',
#   'earphone',
#   'storage',
#   'virtual',
#   'lesson'],
#  ['help',
#   'student',
#   'ipad',
#   'pro',
#   'apple',
#   'pencil',
#   'apple',
#   'keyboard',
#   'help',
#   'succeed',
#   'college'],
#  ['help',
#   'student',
#   'supply',
#   'go',
#   'distance',
#   'learning',
#   'summer',
#   'vacation',
#   'include',
#   'book',
#   'math',
#   'flash',
#   'card',
#   'drawing',
#   'write',
#   'supply',
#   'distance_learning'],
#  ['help',
#   'student',
#   'supply',
#   'desperately',
#   'need',
#   'home',
#   'continue',
#   'satiate',
#   'thirst',
#   'knowledge'],
#  ['help',
#   'student',
#   'visual',
#   'representation',
#   'learn',
#   'zoom',
#   'paper',
#   'teacher',
#   'send',
#   'miss',
#   'card'],
#  ['help',
#   'student',
#   'cozy',
#   'carpet',
#   'space',
#   'perfect',
#   'group',
#   'collaboration',
#   'time',
#   'quiet',
#   'place',
#   'sit',
#   'independent',
#   'reading',
#   'time',
#   'sit',
#   'cold',
#   'tile',
#   'floor',
#   'comfortable'],
#  ['help', 'student', 'lenovo', 'chromebook', 'learn', 'stock', 'market'],
#  ['help',
#   'student',
#   'bulletin',
#   'board',
#   'supply',
#   'butcher',
#   'paper',
#   'border',
#   'classroom',
#   'happy',
#   'welcoming',
#   'environment'],
#  ['help',
#   'student',
#   'book',
#   'library',
#   'represent',
#   'culture',
#   'lesson',
#   'learn'],
#  ['help',
#   'student',
#   'large',
#   'sensory',
#   'item',
#   'include',
#   'trampoline',
#   'bubble',
#   'tube',
#   'sensory',
#   'light',
#   'new',
#   'sensory',
#   'room'],
#  ['help',
#   'student',
#   'good',
#   'possible',
#   'remote',
#   'classroom',
#   'teacher',
#   'provide',
#   'webcam',
#   'green',
#   'screen',
#   'headphone'],
#  ['help',
#   'student',
#   'puppet',
#   'learn',
#   'letter',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help',
#   'student',
#   'base',
#   'block',
#   'help',
#   'conceptually',
#   'learn',
#   'add',
#   'subtract',
#   'regrouping'],
#  ['help', 'student', 'tool', 'writing', 'process', 'engaging'],
#  ['help',
#   'student',
#   'wonderful',
#   'collection',
#   'nonfiction',
#   'book',
#   'provide',
#   'variety',
#   'hand',
#   'stem',
#   'science',
#   'investigation',
#   'include',
#   'exciting',
#   'nonfiction',
#   'anchor',
#   'text',
#   'video',
#   'quench',
#   'thirst'],
#  ['help', 'student', 'lenovo', 'chromebook', 'learn', 'stock', 'market'],
#  ['help', 'student', 'picasso', 'tile', 'block', 'rock', 'soft', 'start'],
#  ['help',
#   'student',
#   'structure',
#   'physical',
#   'education',
#   'day',
#   'school',
#   'year',
#   'school_year'],
#  ['help',
#   'student',
#   'magic',
#   'music',
#   'ocarina',
#   'precursor',
#   'recorder',
#   'large',
#   'hole',
#   'compatible',
#   'successful',
#   'poor',
#   'fine',
#   'motor',
#   'skill',
#   'year',
#   'old'],
#  ['help',
#   'student',
#   'big',
#   'social',
#   'emotional',
#   'library',
#   'therapeutic',
#   'game',
#   'support',
#   'social',
#   'emotional',
#   'behavioral',
#   'development',
#   'want',
#   'provide',
#   'safe',
#   'therapeutic',
#   'space',
#   'learn',
#   'grow',
#   'social_emotional',
#   'social_emotional'],
#  ['help',
#   'student',
#   'piece',
#   'real',
#   'estate',
#   'school',
#   'kid',
#   'carpet',
#   'square',
#   'day',
#   'practice',
#   'social',
#   'distancing'],
#  ['help',
#   'student',
#   'fact',
#   'base',
#   'material',
#   'supply',
#   'reflect',
#   'current',
#   'event'],
#  ['help',
#   'student',
#   'tool',
#   'include',
#   'cricut',
#   'explore',
#   'air',
#   'expand',
#   'knowledge',
#   'stem',
#   'field',
#   'graphic',
#   'design',
#   'commercial',
#   'photography',
#   'student',
#   'club',
#   'technology',
#   'student',
#   'association'],
#  ['help',
#   'student',
#   'book',
#   'showcase',
#   'diversity',
#   'inclusion',
#   'classroom'],
#  ['help',
#   'student',
#   'chalk',
#   'marker',
#   'fun',
#   'exciting',
#   'art',
#   'project',
#   'help',
#   'create',
#   'engage',
#   'stem',
#   'science',
#   'project',
#   'human',
#   'body',
#   'unit',
#   'help',
#   'enhance',
#   'student',
#   'understanding',
#   'learn',
#   'rolling',
#   'whiteboard',
#   'magnetic',
#   'paper',
#   'chart'],
#  ['help',
#   'student',
#   'access',
#   'high',
#   'quality',
#   'non',
#   'fiction',
#   'text',
#   'class',
#   'scholastic',
#   'magazine',
#   'subscription'],
#  ['help', 'student', 'opportunity', 'connect', 'engage', 'learning'],
#  ['help',
#   'student',
#   'quality',
#   'instruction',
#   'document',
#   'camera',
#   'headphone',
#   'build',
#   'microphone',
#   'document_camera'],
#  ['help',
#   'student',
#   'right',
#   'book',
#   'student',
#   'grow',
#   'need',
#   'new',
#   'book',
#   'fill',
#   'library'],
#  ['help',
#   'student',
#   'sensory',
#   'star',
#   'beanbag',
#   'silly',
#   'shape',
#   'sensory',
#   'mat',
#   'textured',
#   'rubbing',
#   'plate'],
#  ['help', 'student', 'supply', 'learn', 'summer'],
#  ['help',
#   'student',
#   'new',
#   'black',
#   'athletic',
#   'reversible',
#   'top',
#   'pair',
#   'short'],
#  ['help',
#   'student',
#   'lego',
#   'education',
#   'set',
#   'create',
#   'collaborate',
#   'fellow',
#   'classmate'],
#  ['help',
#   'student',
#   'new',
#   'set',
#   'brachiopod',
#   'fossil',
#   'plate',
#   'explore',
#   'like',
#   'real',
#   'paleontologist'],
#  ['help',
#   'student',
#   'way',
#   'store',
#   'music',
#   'stand',
#   'help',
#   'save',
#   'valuable',
#   'space',
#   'classroom',
#   'have',
#   'stand',
#   'cart',
#   'greatly',
#   'help',
#   'classroom'],
#  ['need',
#   'attend',
#   'teach',
#   'conference',
#   'teach',
#   'way',
#   'create',
#   'experience',
#   'classroom',
#   'student',
#   'engage',
#   'learning'],
#  ['help', 'student', 'laptop', 'use', 'online', 'learning', 'continue'],
#  ['help', 'student', 'laptop', 'technological', 'college'],
#  ['help', 'student', 'laptop', 'college', 'graduate', 'high', 'school'],
#  ['help',
#   'student',
#   'necessary',
#   'supply',
#   'learn',
#   'home',
#   'backpack',
#   'provide',
#   'supply',
#   'student',
#   'learn',
#   'home'],
#  ['help',
#   'student',
#   'workbook',
#   'continue',
#   'learn',
#   'home',
#   'summer',
#   'student',
#   'need',
#   'extra',
#   'practice',
#   'reading',
#   'writing'],
#  ['help',
#   'student',
#   'flexible',
#   'seating',
#   'option',
#   'work',
#   'classroom',
#   'project',
#   'small',
#   'group',
#   'cooperatively',
#   'flexible_seating'],
#  ['help', 'student', 'owl', 'diary', 'spanish', 'continue', 'love', 'read'],
#  ['help',
#   'student',
#   'book',
#   'level',
#   'comfortable',
#   'seating',
#   'option',
#   'seating_option'],
#  ['help',
#   'student',
#   'define',
#   'space',
#   'carpet',
#   'activity',
#   'opportunity',
#   'meet',
#   'sensory',
#   'need',
#   'sensory',
#   'play',
#   'material'],
#  ['help',
#   'student',
#   'paint',
#   'finish',
#   'amazingly',
#   'powerful',
#   'art',
#   'project'],
#  ['help',
#   'student',
#   'real',
#   'life',
#   'engagement',
#   'distance',
#   'learning',
#   'allow',
#   'capability',
#   'readily',
#   'differentiate',
#   'instruction',
#   'need',
#   'printer',
#   'scan',
#   'material',
#   'distance',
#   'learning',
#   'distance_learning',
#   'distance_learning'],
#  ['help',
#   'student',
#   'ability',
#   'history',
#   'come',
#   'life',
#   'start',
#   'historical',
#   'fiction',
#   'book',
#   'club',
#   'library',
#   'need',
#   'upgrade',
#   'accommodate',
#   'new',
#   'unit'],
#  ['help', 'student', 'opportunity', 'use', 'technology', 'classroom', 'ipad'],
#  ['help',
#   'student',
#   'multicultural',
#   'diverse',
#   'doll',
#   'explore',
#   'dramatic',
#   'play'],
#  ['help', 'student', 'cute', 'matching', 'shoe', 'wear', 'cheer', 'team'],
#  ['help',
#   'student',
#   'college',
#   'planning',
#   'material',
#   'help',
#   'motivated',
#   'summer'],
#  ['help', 'student', 'book', 'use', 'novel', 'study'],
#  ['help',
#   'student',
#   'online',
#   'resource',
#   'teacher',
#   'pay',
#   'teacher',
#   'learn',
#   'home'],
#  ['help',
#   'student',
#   'collection',
#   'board',
#   'book',
#   'borrow',
#   'classroom',
#   'read',
#   'family',
#   'home'],
#  ['help',
#   'student',
#   'paint',
#   'brush',
#   'create',
#   'wonderful',
#   'individual',
#   'artwork',
#   'inspirational',
#   'school',
#   'poster'],
#  ['help', 'student', 'basic', 'essential', 'successful', 'day'],
#  ['help',
#   'student',
#   'organized',
#   'teacher',
#   'material',
#   'need',
#   'online',
#   'learning'],
#  ['help',
#   'student',
#   'find',
#   'letter',
#   'activity',
#   'center',
#   'develop',
#   'literacy',
#   'fine',
#   'motor',
#   'skill',
#   'home',
#   'pandemic',
#   'situation'],
#  ['help',
#   'student',
#   'let',
#   'move',
#   'activity',
#   'mat',
#   'sight',
#   'word',
#   'mat',
#   'number',
#   'letter',
#   'bean',
#   'bag'],
#  ['help',
#   'student',
#   'ability',
#   'classroom',
#   'enjoy',
#   'personal',
#   'space',
#   'have',
#   'soft',
#   'individual',
#   'seating',
#   'classroom',
#   'help',
#   'accomplish'],
#  ['help',
#   'student',
#   'digital',
#   'camera',
#   'memory',
#   'card',
#   'opportunity',
#   'create',
#   'great',
#   'digital',
#   'picture',
#   'creative',
#   'photography',
#   'class'],
#  ['student',
#   'need',
#   'visual',
#   'anchor',
#   'chart',
#   'guide',
#   'reading',
#   'sound',
#   'blocker',
#   'build',
#   'reading',
#   'fluency',
#   'pencil',
#   'box',
#   'store',
#   'manipulative',
#   'activity',
#   'cognitive',
#   'guide',
#   'instruction'],
#  ['help',
#   'student',
#   'opportunity',
#   'interactively',
#   'learn',
#   'biology',
#   'remember',
#   'high',
#   'school',
#   'dissection',
#   'lab',
#   'want',
#   'able',
#   'student',
#   'chance'],
#  ['help',
#   'student',
#   'certificate',
#   'achievement',
#   'photo',
#   'collage',
#   'photo',
#   'paper',
#   'laptop',
#   'accessory',
#   'ink',
#   'copy',
#   'web',
#   'cam',
#   'online',
#   'graduation',
#   'gift',
#   'student'],
#  ['help',
#   'student',
#   'book',
#   'promise',
#   'bear',
#   'disappoint',
#   'pick',
#   'title',
#   'want',
#   'read',
#   'summer',
#   'let'],
#  ['help',
#   'student',
#   'individual',
#   'copy',
#   'baby',
#   'touch',
#   'feel',
#   'count',
#   'book'],
#  ['help',
#   'student',
#   'prepare',
#   'easy',
#   'understand',
#   'lesson',
#   'document',
#   'camera',
#   'webcam',
#   'document_camera'],
#  ['help', 'student', 'engage', 'graphic', 'novel', 'don', 'forget', 'read'],
#  ['help',
#   'student',
#   'individual',
#   'apple',
#   'smart',
#   'kid',
#   'trace',
#   'flip',
#   'book',
#   'help',
#   'learn',
#   'alphabet',
#   'letter',
#   'write',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help',
#   'student',
#   'book',
#   'people',
#   'make',
#   'positive',
#   'difference',
#   'world'],
#  ['help',
#   'student',
#   'student',
#   'copy',
#   'book',
#   'head',
#   'look',
#   'big',
#   'randa',
#   'abdel',
#   'fattah',
#   'continue',
#   'exploration',
#   'different',
#   'cultural',
#   'perspective',
#   'world',
#   'literature'],
#  ['help',
#   'student',
#   'ink',
#   'printer',
#   'paper',
#   'material',
#   'provide',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help', 'student', 'complete', 'dorm', 'bed', 'set', 'dorm'],
#  ['help',
#   'student',
#   'book',
#   'celebrate',
#   'diversity',
#   'help',
#   'explain',
#   'history',
#   'racism'],
#  ['student',
#   'need',
#   'seat',
#   'storage',
#   'sack',
#   'storage',
#   'underneath',
#   'desk',
#   'student',
#   'need',
#   'learn',
#   'mobile',
#   'teaching',
#   'easel',
#   'way',
#   'learning',
#   'follow',
#   'desk',
#   'carpet',
#   'station'],
#  ['help',
#   'student',
#   'calm',
#   'corner',
#   'help',
#   'learn',
#   'manage',
#   'feeling',
#   'fountain',
#   'art',
#   'board',
#   'puzzle',
#   'calm',
#   'music'],
#  ['help',
#   'student',
#   'virtual',
#   'classroom',
#   'library',
#   'distance',
#   'learn',
#   'diverse',
#   'set',
#   'chapter',
#   'book',
#   'classroom_library'],
#  ['help', 'student', 'complete', 'dorm', 'bed', 'set', 'dorm'],
#  ['help',
#   'student',
#   'variety',
#   'easy',
#   'prepare',
#   'food',
#   'snack',
#   'water',
#   'drawing',
#   'board'],
#  ['help',
#   'student',
#   'opportunity',
#   'create',
#   'great',
#   'digital',
#   'picture',
#   'creative',
#   'photography',
#   'class'],
#  ['help',
#   'student',
#   'sew',
#   'machine',
#   'sew',
#   'quilt',
#   'bake',
#   'supply',
#   'decorate',
#   'cookie',
#   'love',
#   'one'],
#  ['help', 'student', 'new', 'training', 'equipment', 'practice', 'session'],
#  ['help',
#   'student',
#   'laptop',
#   'able',
#   'work',
#   'independently',
#   'time',
#   'have',
#   'share',
#   'rest',
#   'family'],
#  ['help',
#   'student',
#   'plant',
#   'live',
#   'brighten',
#   'classroom',
#   'return',
#   'school'],
#  ['help',
#   'student',
#   'good',
#   'home',
#   'away',
#   'home',
#   'flexible',
#   'seating',
#   'option',
#   'dry',
#   'erase',
#   'sheet',
#   'protector',
#   'whiteboard',
#   'eraser',
#   'flexible_seating',
#   'dry_erase'],
#  ['help',
#   'student',
#   'access',
#   'technology',
#   'classroom',
#   'implementation',
#   'amazon',
#   'fire',
#   'tablet'],
#  ['help',
#   'student',
#   'real',
#   'time',
#   'problem',
#   'solve',
#   'wacom',
#   'tablet',
#   'able',
#   'solve',
#   'problem',
#   'diagram',
#   'student',
#   'online',
#   'real',
#   'time',
#   'record',
#   'solution',
#   'use',
#   'later'],
#  ['help',
#   'student',
#   'organization',
#   'binder',
#   'curriculum',
#   'document',
#   'bookshelf',
#   'white',
#   'board',
#   'book',
#   'storage',
#   'bins',
#   'classroom',
#   'material',
#   'storage',
#   'cart'],
#  ['help',
#   'student',
#   'abundance',
#   'online',
#   'resource',
#   'engage',
#   'learning',
#   'physically',
#   'school',
#   'right'],
#  ['help', 'student', 'read', 'rod', 'ink', 'cartridges', 'hand', 'sanitizer'],
#  ['help',
#   'student',
#   'technology',
#   'read',
#   'school',
#   'home',
#   'new',
#   'fire',
#   'tablet'],
#  ['help',
#   'student',
#   'item',
#   'classroom',
#   'store',
#   'student',
#   'spend',
#   'hard',
#   'earn',
#   'class',
#   'money'],
#  ['need',
#   'help',
#   'work',
#   'fund',
#   'virtual',
#   'conference',
#   'summer',
#   'attend',
#   'training',
#   'student'],
#  ['help',
#   'student',
#   'new',
#   'printer',
#   'ink',
#   'paper',
#   'math',
#   'computer',
#   'need',
#   'reference',
#   'sheet',
#   'note'],
#  ['help', 'student', 'ability', 'handwritten', 'graphs', 'formula', 'note'],
#  ['help',
#   'student',
#   'pencil',
#   'crayon',
#   'dry',
#   'erase',
#   'marker',
#   'board',
#   'learn',
#   'home',
#   'dry_erase'],
#  ['help',
#   'student',
#   'meaningful',
#   'book',
#   'social',
#   'justice',
#   'make',
#   'change',
#   'world',
#   'book',
#   'like',
#   'intersection',
#   'ally',
#   'room',
#   'march',
#   'help',
#   'start',
#   'new',
#   'conversation'],
#  ['help', 'student', 'tool', 'need', 'successful', 'college'],
#  ['help',
#   'student',
#   'backpack',
#   'fill',
#   'distance',
#   'learning',
#   'material',
#   'summer',
#   'distance_learning'],
#  ['help',
#   'student',
#   'supply',
#   'reward',
#   'need',
#   'motivate',
#   'engage',
#   'math',
#   'class',
#   'time'],
#  ['help',
#   'student',
#   'chromebook',
#   'transition',
#   'college',
#   'little',
#   'bit',
#   'easy',
#   'time',
#   'covid'],
#  ['help', 'student', 'joy', 'adventure', 'book', 'bring'],
#  ['help',
#   'student',
#   'flexibility',
#   'handing',
#   'assignment',
#   'chance',
#   'receive',
#   'thorough',
#   'answer',
#   'question',
#   'new',
#   'teacher',
#   'ipad'],
#  ['help',
#   'student',
#   'osmo',
#   'system',
#   'ipad',
#   'spell',
#   'math',
#   'word',
#   'problem',
#   'game',
#   'learning',
#   'new',
#   'level'],
#  ['help', 'student', 'lesson', 'deserve', 'remotely', 'home'],
#  ['help',
#   'student',
#   'opportunity',
#   'learn',
#   'vital',
#   'social',
#   'emotional',
#   'skill',
#   'specialized',
#   'book',
#   'game',
#   'material',
#   'social_emotional'],
#  ['help', 'student', 'favorite', 'elephant', 'piggie', 'book', 'read'],
#  ['help',
#   'student',
#   'new',
#   'way',
#   'love',
#   'learn',
#   'need',
#   'flexible',
#   'seating',
#   'flexible_seating'],
#  ['help', 'student', 'book', 'new', 'way', 'dream', 'use', 'imagination'],
#  ['help',
#   'student',
#   'integrate',
#   'technology',
#   'tool',
#   'nearpod',
#   'subscription',
#   'support',
#   'english',
#   'language',
#   'learner'],
#  ['help',
#   'student',
#   'high',
#   'interest',
#   'book',
#   'foster',
#   'love',
#   'reading',
#   'high_interest'],
#  ['help',
#   'student',
#   'reading',
#   'book',
#   'twistable',
#   'crayon',
#   'water',
#   'paint',
#   'bubble',
#   'wand',
#   'use',
#   'learn',
#   'form',
#   'home'],
#  ['help', 'student', 'headphone', 'zoom', 'learn', 'online', 'distraction'],
#  ['help',
#   'student',
#   'resource',
#   'available',
#   'tpt',
#   'gift',
#   'card',
#   'access',
#   'differentiate',
#   'learn',
#   'opportunity'],
#  ['help',
#   'student',
#   'tablets',
#   'art',
#   'supply',
#   'healthy',
#   'snack',
#   'help',
#   'fuel',
#   'brain'],
#  ['help',
#   'student',
#   'opportunity',
#   'read',
#   'modern',
#   'book',
#   'topic',
#   'matter',
#   'wall',
#   'john',
#   'lanchester',
#   'give',
#   'student',
#   'great',
#   'opportunity',
#   'discuss',
#   'change',
#   'world'],
#  ['help',
#   'student',
#   'jump',
#   'start',
#   'close',
#   'digital',
#   'divide',
#   'computer'],
#  ['help',
#   'student',
#   'material',
#   'support',
#   'inclusion',
#   'special',
#   'need',
#   'child',
#   'high',
#   'interest',
#   'hand',
#   'material',
#   'tool',
#   'self',
#   'regulation',
#   'high_interest'],
#  ['help',
#   'student',
#   'black',
#   'white',
#   'laser',
#   'printer',
#   'opportunity',
#   'access',
#   'digital',
#   'document',
#   'teacher',
#   'feedback',
#   'frequently',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help', 'student', 'novel', 'difference', 'world'],
#  ['help', 'student', 'book', 'fill', 'mobile', 'library', 'read'],
#  ['help',
#   'student',
#   'disinfect',
#   'material',
#   'fight',
#   'common',
#   'cold',
#   'reduce',
#   'germ',
#   'classroom',
#   'printer',
#   'allow',
#   'student',
#   'utilize',
#   'colorful',
#   'resource',
#   'learn'],
#  ['help', 'student', 'ink', 'print', 'sheet', 'send'],
#  ['help',
#   'student',
#   'book',
#   'read',
#   'home',
#   'access',
#   'school',
#   'public',
#   'library'],
#  ['help', 'student', 'circuit', 'playground', 'battery', 'accessory'],
#  ['help', 'student', 'optional', 'seating', 'learn', 'good', 'ability'],
#  ['help',
#   'student',
#   'fresh',
#   'start',
#   'new',
#   'year',
#   'flexible',
#   'seat',
#   'way',
#   'room',
#   'comfortable',
#   'way',
#   'wobble',
#   'chair',
#   'life',
#   'change',
#   'huge',
#   'impact'],
#  ['help',
#   'student',
#   'material',
#   'support',
#   'learning',
#   'home',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help', 'student', 'supply', 'create', 'awesome', 'art', 'happy', 'art'],
#  ['help', 'student', 'access', 'school', 'material', 'digitally', 'learn'],
#  ['help', 'student', 'place', 'store', 'reading', 'book', 'week'],
#  ['help',
#   'student',
#   'opportunity',
#   'learn',
#   'badminton',
#   'fun',
#   'fill',
#   'sport'],
#  ['help', 'student', 'reliable', 'new', 'headphone', 'use', 'computer'],
#  ['help',
#   'student',
#   'treat',
#   'snack',
#   'go',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help', 'student', 'voice', 'hear', 'student', 'classroom'],
#  ['help',
#   'student',
#   'essential',
#   'material',
#   'create',
#   'awesome',
#   'art',
#   'project',
#   'student',
#   'deserve',
#   'chance',
#   'explore',
#   'art',
#   'fundamental',
#   'art',
#   'supply'],
#  ['help',
#   'student',
#   'tiger',
#   'run',
#   'club',
#   'shirt',
#   'foster',
#   'team',
#   'unity',
#   'run',
#   'club'],
#  ['help', 'student', 'tool', 'help', 'learn', 'help', 'relax'],
#  ['help',
#   'student',
#   'literacy',
#   'game',
#   'chapter',
#   'book',
#   'push',
#   'skill',
#   'student',
#   'perform',
#   'grade',
#   'level'],
#  ['help',
#   'student',
#   'access',
#   'powerful',
#   'visual',
#   'resource',
#   'polish',
#   'final',
#   'product',
#   'color',
#   'printer'],
#  ['help',
#   'student',
#   'book',
#   'ignite',
#   'curiosity',
#   'integrity',
#   'help',
#   'grapple',
#   'big',
#   'question',
#   'society'],
#  ['help',
#   'student',
#   'opportunity',
#   'use',
#   'glass',
#   'supply',
#   'create',
#   'glass',
#   'fusing',
#   'stain',
#   'glass',
#   'project'],
#  ['help',
#   'student',
#   'math',
#   'manipulative',
#   'resource',
#   'need',
#   'order',
#   'succeed'],
#  ['help',
#   'student',
#   'material',
#   'use',
#   'engage',
#   'multi',
#   'dimensional',
#   'learning',
#   'activity',
#   'online',
#   'learning',
#   'need',
#   'classroom'],
#  ['help',
#   'student',
#   'interesting',
#   'engage',
#   'book',
#   'classroom',
#   'library',
#   'classroom_library'],
#  ['help',
#   'student',
#   'introduction',
#   'stem',
#   'spacial',
#   'creativity',
#   'building',
#   'material',
#   'storage'],
#  ['help',
#   'student',
#   'supply',
#   'project',
#   'need',
#   'styrofoam',
#   'ball',
#   'model',
#   'planet',
#   'moon',
#   'grey',
#   'screen',
#   'set',
#   'student',
#   'video',
#   'presentation',
#   'printer',
#   'toner',
#   'print',
#   'work'],
#  ['help',
#   'student',
#   'material',
#   'create',
#   'project',
#   'connect',
#   'expand',
#   'learning'],
#  ['help',
#   'student',
#   'classroom',
#   'library',
#   'resource',
#   'choose',
#   'conduct',
#   'research',
#   'project',
#   'day',
#   'unit',
#   'student',
#   'choose',
#   'subject',
#   'like',
#   'mediation',
#   'cook',
#   'personal',
#   'finance',
#   'physical',
#   'fitness',
#   'high',
#   'interest',
#   'topic',
#   'classroom_library',
#   'high_interest'],
#  ['help',
#   'student',
#   'math',
#   'game',
#   'activity',
#   'play',
#   'home',
#   'teacher',
#   'author'],
#  ['help',
#   'student',
#   'material',
#   'conduct',
#   'couple',
#   'science',
#   'experiment',
#   'use',
#   'hot',
#   'plate',
#   'hot',
#   'pot',
#   'thermometer'],
#  ['help',
#   'student',
#   'tool',
#   'organize',
#   'learn',
#   'space',
#   'optimize',
#   'academic',
#   'success'],
#  ['help', 'student', 'new', 'tape', 'measure', 'promote', 'lifelong', 'skill'],
#  ['help', 'student', 'book', 'teach', 'student', 'seven', 'continent'],
#  ['help',
#   'student',
#   'book',
#   'allow',
#   'hand',
#   'project',
#   'base',
#   'learn',
#   'area',
#   'leadership',
#   'business',
#   'financial',
#   'math'],
#  ['help',
#   'student',
#   'access',
#   'good',
#   'literature',
#   'expose',
#   'narrative',
#   'think',
#   'critically',
#   'world'],
#  ['help',
#   'student',
#   'entire',
#   'elementary',
#   'school',
#   'playground',
#   'equipment',
#   'upgrade',
#   'soccer',
#   'ball',
#   'volleyball',
#   'net',
#   'sport',
#   'student',
#   'active',
#   'recess',
#   'option'],
#  ['help', 'student', 'opportunity', 'learn', 'exploration', 'creativity'],
#  ['help',
#   'student',
#   'assortment',
#   'classroom',
#   'supply',
#   'space',
#   'stocked',
#   'safe',
#   'creative',
#   'environment',
#   'facial',
#   'tissue',
#   'sanitizer',
#   'craft',
#   'supply',
#   'pen',
#   'pencil',
#   'oil',
#   'pastel',
#   'etc'],
#  ['help', 'student', 'copy', 'book', 'boy', 'class'],
#  ['help',
#   'student',
#   'copy',
#   'harry',
#   'potter',
#   'sorcerer',
#   'stone',
#   'listen',
#   'read',
#   'practice'],
#  ['help',
#   'student',
#   'personalized',
#   'shirt',
#   'create',
#   'heat',
#   'press',
#   'machine',
#   'pair',
#   'protective',
#   'heat',
#   'mat',
#   'cricut'],
#  ['help', 'student', 'gym', 'professional', 'perform', 'skill'],
#  ['help',
#   'student',
#   'write',
#   'material',
#   'counting',
#   'game',
#   'marble',
#   'run',
#   'journal'],
#  ['help', 'student', 'book', 'enjoy', 'read', 'school'],
#  ['help',
#   'student',
#   'engage',
#   'material',
#   'math',
#   'provide',
#   'long',
#   'time',
#   'learn'],
#  ['help', 'student', 'happy', 'mail', 'love', 'send', 'postcard'],
#  ['help', 'student', 'variety', 'book', 'enjoy', 'home'],
#  ['help',
#   'student',
#   'roll',
#   'cart',
#   'store',
#   'supply',
#   'book',
#   'organized',
#   'way',
#   'immediate',
#   'access',
#   'material'],
#  ['help',
#   'student',
#   'wonder',
#   'stix',
#   'stanley',
#   'stapler',
#   'stanley',
#   'sharpshooter',
#   'stapler'],
#  ['help',
#   'student',
#   'classroom',
#   'library',
#   'celebrate',
#   'uniqueness',
#   'diversity',
#   'classroom_library'],
#  ['help',
#   'student',
#   'opportunity',
#   'explore',
#   'science',
#   'technology',
#   'engineering',
#   'art',
#   'math',
#   'steam',
#   'independently',
#   'use',
#   'busy',
#   'bucket',
#   'fill',
#   'engaging',
#   'creative',
#   'activity'],
#  ['help',
#   'student',
#   'vinyl',
#   'create',
#   'shirt',
#   'field',
#   'day',
#   'elementary',
#   'school'],
#  ['help', 'student', 'good', 'equipment', 'use', 'perform', 'high', 'level'],
#  ['help',
#   'student',
#   'target',
#   'set',
#   'use',
#   'home',
#   'build',
#   'coordination',
#   'distance',
#   'learn',
#   'physical',
#   'fitness'],
#  ['help',
#   'student',
#   'mentor',
#   'text',
#   'engage',
#   'reading',
#   'writing',
#   'lesson'],
#  ['help', 'student', 'opportunity', 'rock', 'recorder'],
#  ['help',
#   'student',
#   'opportunity',
#   'learn',
#   'use',
#   'technology',
#   'ipad',
#   'open',
#   'door',
#   'hundred',
#   'way',
#   'engage',
#   'enhance',
#   'extend',
#   'daily',
#   'learning',
#   'classroom',
#   'wall'],
#  ['help',
#   'student',
#   'flexspace',
#   'student',
#   'lap',
#   'desk',
#   'portable',
#   'move',
#   'room',
#   'easily'],
#  ['help', 'student', 'look', 'school', 'home', 'time'],
#  ['help',
#   'student',
#   'phonic',
#   'read',
#   'write',
#   'resource',
#   'engaging',
#   'fun',
#   'welcome',
#   'crazy',
#   'scary',
#   'coronavirus',
#   'shutdown'],
#  ['help',
#   'student',
#   'math',
#   'manipulative',
#   'material',
#   'book',
#   'write',
#   'workbook',
#   'help',
#   'home'],
#  ['help', 'student', 'headphone', 'work', 'chromebook', 'book', 'read'],
#  ['help',
#   'student',
#   'hand',
#   'science',
#   'experience',
#   'provide',
#   'ecosystem',
#   'classroom'],
#  ['help',
#   'student',
#   'sensory',
#   'item',
#   'sensory',
#   'room',
#   'body',
#   'sock',
#   'art',
#   'liquid',
#   'tile',
#   'sensory',
#   'tool',
#   'help',
#   'build',
#   'safe',
#   'place',
#   'student',
#   'come',
#   'regulate',
#   'body',
#   'emotion'],
#  ['help',
#   'student',
#   'cricut',
#   'explore',
#   'cutter',
#   'create',
#   'endless',
#   'possibility'],
#  ['help',
#   'student',
#   'wobble',
#   'stool',
#   'support',
#   'active',
#   'sitting',
#   'classroom'],
#  ['help',
#   'student',
#   'ability',
#   'read',
#   'book',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help',
#   'student',
#   'technology',
#   'need',
#   'successful',
#   'college',
#   'begin',
#   'new',
#   'chapter',
#   'life'],
#  ['help',
#   'student',
#   'social',
#   'emotional',
#   'tool',
#   'need',
#   'successful',
#   'include',
#   'manage',
#   'stress',
#   'journale',
#   'creative',
#   'social_emotional'],
#  ['student',
#   'need',
#   'document',
#   'camera',
#   'enhance',
#   'interaction',
#   'language',
#   'writing',
#   'enforce',
#   'deep',
#   'classroom',
#   'discussion',
#   'participation',
#   'document_camera'],
#  ['help',
#   'student',
#   'access',
#   'engage',
#   'curriculum',
#   'person',
#   'remote',
#   'learning',
#   'wonder',
#   'curriculum',
#   'plan',
#   'teacher',
#   'pay',
#   'teacher',
#   'like',
#   'gift',
#   'student',
#   'copy',
#   'wonder',
#   'remote_learning'],
#  ['help',
#   'student',
#   'touch',
#   'screen',
#   'tablet',
#   'headphone',
#   'access',
#   'academic',
#   'program',
#   'easy'],
#  ['help',
#   'student',
#   'access',
#   'earth',
#   'unit',
#   'donate',
#   'material',
#   'write',
#   'grow',
#   'plant',
#   'count',
#   'use',
#   'imagination'],
#  ['help',
#   'student',
#   'balance',
#   'ball',
#   'seat',
#   'flexible',
#   'seating',
#   'option',
#   'promote',
#   'health',
#   'wellness',
#   'flexible_seating'],
#  ['help', 'student', 'ability', 'literature', 'art'],
#  ['help',
#   'student',
#   'ipad',
#   'charge',
#   'cart',
#   'technology',
#   'charge',
#   'organize'],
#  ['help',
#   'student',
#   'moveable',
#   'dry',
#   'erase',
#   'board',
#   'magnet',
#   'easily',
#   'teach',
#   'distance',
#   'learning',
#   'dry_erase',
#   'distance_learning'],
#  ['help',
#   'student',
#   'school',
#   'supply',
#   'social',
#   'study',
#   'project',
#   'class'],
#  ['help',
#   'student',
#   'appropriate',
#   'way',
#   'relieve',
#   'stress',
#   'start',
#   'college',
#   'enter',
#   'workforce',
#   'stressful',
#   'time',
#   'normal',
#   'circumstance',
#   'experience',
#   'thing',
#   'worldwide',
#   'pandemic',
#   'stressful'],
#  ['help',
#   'student',
#   'quality',
#   'distance',
#   'learn',
#   'opportunity',
#   'use',
#   'printer',
#   'ink',
#   'gift',
#   'card',
#   'digital',
#   'resource',
#   'teacher',
#   'pay',
#   'teacher'],
#  ['help', 'student', 'cotizone', 'help', 'ease', 'discomfort', 'eczema'],
#  ['help',
#   'student',
#   'banjolele',
#   'play',
#   'different',
#   'timbre',
#   'folk',
#   'country',
#   'music'],
#  ['help',
#   'student',
#   'comfortable',
#   'learning',
#   'environment',
#   'grant',
#   'encompass',
#   'voice',
#   'love',
#   'classroom'],
#  ['help',
#   'student',
#   'writing',
#   'utensil',
#   'color',
#   'chart',
#   'plan',
#   'book',
#   'continue',
#   'plan',
#   'distance',
#   'lesson'],
#  ['help',
#   'student',
#   'class',
#   'personalized',
#   'shirt',
#   'slide',
#   'photograph',
#   'music',
#   'commemorate',
#   'accomplishment'],
#  ['help',
#   'student',
#   'light',
#   'sound',
#   'stage',
#   'makeup',
#   'complete',
#   'school',
#   'musical',
#   'production'],
#  ['help',
#   'student',
#   'class',
#   'set',
#   'novel',
#   'brave',
#   'novel',
#   'study',
#   'rigorous',
#   'engage',
#   'text',
#   'character',
#   'look',
#   'like',
#   'student'],
#  ['help',
#   'student',
#   'amazing',
#   'writer',
#   'workshop',
#   'experience',
#   'provide',
#   'write',
#   'radar',
#   'jack',
#   'gantos',
#   'dell',
#   'latitude',
#   'laptop',
#   'help',
#   'provide',
#   'timely',
#   'meaningful',
#   'feedback'],
#  ['help',
#   'student',
#   'variety',
#   'graphic',
#   'novel',
#   'range',
#   'historical',
#   'text',
#   'like',
#   'call',
#   'enemy',
#   'japanese',
#   'internment',
#   'camp',
#   'popular',
#   'read',
#   'batman',
#   'star',
#   'war'],
#  ['help',
#   'student',
#   'optimal',
#   'environment',
#   'comfort',
#   'collaboration',
#   'productivity',
#   'sensory',
#   'stimulation',
#   'flexible',
#   'seating',
#   'flexible_seating'],
#  ['help',
#   'student',
#   'hand',
#   'cross',
#   'curricular',
#   'experience',
#   'real',
#   'life',
#   'butterfly'],
#  ['help',
#   'student',
#   'sphero',
#   'charge',
#   'case',
#   'robot',
#   'easy',
#   'accessibility',
#   'charge'],
#  ['help',
#   'student',
#   'apple',
#   'macbook',
#   'pro',
#   'touch',
#   'bar',
#   'core',
#   'ram',
#   'ssd'],
#  ['help',
#   'student',
#   'book',
#   'feature',
#   'diverse',
#   'character',
#   'reflect',
#   'diverse',
#   'population',
#   'school'],
#  ['help', 'student', 'opportunity', 'engage', 'art', 'home'],
#  ['help',
#   'student',
#   'workbook',
#   'prevent',
#   'summer',
#   'slide',
#   'hone',
#   'skill',
#   'grade'],
#  ['help', 'student', 'hygiene', 'item', 'healthy', 'snack', 'home'],
#  ['help',
#   'student',
#   'wholesome',
#   'snack',
#   'option',
#   'include',
#   'pretzel',
#   'breakfast',
#   'bar',
#   'goldfish',
#   'cracker'],
#  ['help',
#   'student',
#   'classroom',
#   'supply',
#   'math',
#   'science',
#   'activity',
#   'need',
#   'home',
#   'schooling'],
#  ['help', 'student', 'student', 'fresh', 'new', 'carpet', 'sit', 'learn'],
#  ['help', 'student', 'basic', 'supply', 'activity', 'home', 'new', 'school'],
#  ['help',
#   'student',
#   'opportunity',
#   'learn',
#   'remote',
#   'learning',
#   'ipad',
#   'remote_learning'],
#  ['help', 'student', 'hygiene', 'product', 'snack', 'home', 'pandemic'],
#  ['help',
#   'student',
#   'tool',
#   'need',
#   'create',
#   'year',
#   'long',
#   'campus',
#   'newspaper'],
#  ['help',
#   'student',
#   'new',
#   'wrest',
#   'singlet',
#   'headgear',
#   'current',
#   'equipment',
#   'year',
#   'old',
#   'want',
#   'student',
#   'opportunity',
#   'participate'],
#  ['help',
#   'student',
#   'opportunity',
#   'explore',
#   'level',
#   'art',
#   'creation',
#   'set',
#   'material',
#   'order',
#   'special',
#   'student',
#   'grade',
#   'show',
#   'exceptional',
#   'talent'],
#  ['help',
#   'student',
#   'picture',
#   'book',
#   'begin',
#   'diversity',
#   'world',
#   'outside',
#   'small',
#   'community'],
#  ['help',
#   'student',
#   'tablet',
#   'learn',
#   'english',
#   'translate',
#   'classwork',
#   'native',
#   'language'],
#  ['help',
#   'student',
#   'saucer',
#   'swing',
#   'stand',
#   'weight',
#   'blanket',
#   'sensory',
#   'sock',
#   'chair',
#   'ball',
#   'light',
#   'projector',
#   'enhance',
#   'sensory',
#   'room',
#   'meet',
#   'need',
#   'student',
#   'sensory',
#   'need'],
#  ['help',
#   'student',
#   'movement',
#   'flexible',
#   'seating',
#   'option',
#   'focus',
#   'learn',
#   'different',
#   'seating',
#   'option',
#   'seat',
#   'table',
#   'flexible_seating',
#   'seating_option'],
#  ['help',
#   'student',
#   'chromebook',
#   'use',
#   'access',
#   'google',
#   'classroom',
#   'online',
#   'assignment'],
#  ['help', 'student', 'personalize', 'incentive', 'come', 'online', 'school'],
#  ['help',
#   'student',
#   'needed',
#   'snack',
#   'need',
#   'school',
#   'supply',
#   'continue',
#   'distance',
#   'learn',
#   'deserve',
#   'nourishment',
#   'fuel',
#   'body',
#   'school',
#   'supply',
#   'continue',
#   'good',
#   'work'],
#  ['help',
#   'student',
#   'flannel',
#   'storytelling',
#   'set',
#   'book',
#   'create',
#   'lively',
#   'virtual',
#   'story',
#   'time'],
#  ['help',
#   'student',
#   'doodler',
#   'pen',
#   'help',
#   'create',
#   'explore',
#   'way',
#   'idea',
#   'come',
#   'life',
#   'student',
#   'able',
#   'prototype',
#   'fashion'],
#  ['help', 'student', 'math', 'manipulative', 'activity', 'use', 'center'],
#  ['help',
#   'student',
#   'apple',
#   'macbook',
#   'pro',
#   'touch',
#   'bar',
#   'core',
#   'ram',
#   'ssd'],
#  ['help',
#   'student',
#   'second',
#   'monitor',
#   'wireless',
#   'mouse',
#   'well',
#   'zooming',
#   'experience'],
#  ['help',
#   'student',
#   'story',
#   'create',
#   'representation',
#   'character',
#   'marginalize',
#   'background'],
#  ['help',
#   'student',
#   'subscription',
#   'scholastic',
#   'news',
#   'incorporate',
#   'science',
#   'social',
#   'study',
#   'reading',
#   'lesson'],
#  ['help',
#   'student',
#   'place',
#   'gather',
#   'learn',
#   'build',
#   'community',
#   'friend'],
#  ['help',
#   'student',
#   'flexible',
#   'seating',
#   'clipboard',
#   'safe',
#   'distance',
#   'movement',
#   'classroom',
#   'technology',
#   'piece',
#   'help',
#   'success',
#   'flexible_seating'],
#  ['help',
#   'student',
#   'option',
#   'continue',
#   'learn',
#   'choice',
#   'seat',
#   'classroom'],
#  ['help',
#   'student',
#   'notebook',
#   'folder',
#   'pencil',
#   'pen',
#   'eraser',
#   'sure',
#   'prepare',
#   'distance',
#   'learn',
#   'future'],
#  ['help',
#   'student',
#   'opportunity',
#   'explore',
#   'educational',
#   'website',
#   'use',
#   'chromebook'],
#  ['help',
#   'student',
#   'access',
#   'great',
#   'reading',
#   'material',
#   'covid',
#   'crisis',
#   'book',
#   'select',
#   'awesome',
#   'ensure',
#   'read',
#   'book',
#   'difficult',
#   'time'],
#  ['help',
#   'student',
#   'diverse',
#   'book',
#   'fill',
#   'classroom',
#   'shelf',
#   'diverse',
#   'relatable',
#   'character'],
#  ['help',
#   'student',
#   'sensory',
#   'table',
#   'provide',
#   'endless',
#   'way',
#   'capture',
#   'sensory',
#   'experience',
#   'preschool',
#   'setting',
#   'ice',
#   'explore',
#   'winter',
#   'unit',
#   'dirt',
#   'sift',
#   'etc'],
#  ['help',
#   'student',
#   'care',
#   'package',
#   'necessary',
#   'supply',
#   'glue',
#   'stick',
#   'markers',
#   'color',
#   'pencil',
#   'pencil',
#   'case',
#   'paper',
#   'towel',
#   'need',
#   'item',
#   'snack',
#   'candy',
#   'nearby'],
#  ['help',
#   'student',
#   'glue',
#   'stick',
#   'scissor',
#   'stapler',
#   'staple',
#   'eraser'],
#  ['help',
#   'student',
#   'white',
#   'board',
#   'convert',
#   'tabletop',
#   'dry',
#   'erase',
#   'marker',
#   'wipe',
#   'pocket',
#   'ipad',
#   'holder',
#   'turn',
#   'corner',
#   'office',
#   'distance',
#   'learning',
#   'classroom',
#   'dry_erase',
#   'distance_learning'],
#  ['help',
#   'student',
#   'table',
#   'chromebook',
#   'classroom',
#   'way',
#   'share',
#   'space',
#   'available',
#   'student'],
#  ['help',
#   'student',
#   'book',
#   'continue',
#   'reading',
#   'remote',
#   'learning',
#   'remote_learning'],
#  ['help', 'student', 'lego', 'wedo', 'robotic', 'set', 'stem', 'education'],
#  ['help',
#   'student',
#   'new',
#   'headphone',
#   'school',
#   'radio',
#   'station',
#   'use',
#   'live',
#   'broadcast'],
#  ['student',
#   'need',
#   'read',
#   'write',
#   'game',
#   'encourage',
#   'young',
#   'student',
#   'enjoy',
#   'read',
#   'write',
#   'need',
#   'apple',
#   'ensure',
#   'easy',
#   'transition',
#   'student',
#   'work',
#   'ipad'],
#  ['help', 'student', 'access', 'visual', 'worksheet', 'clear', 'accessible'],
#  ['help',
#   'student',
#   'set',
#   'basic',
#   'school',
#   'supply',
#   'contribution',
#   'help',
#   'student',
#   'loose',
#   'leaf',
#   'paper',
#   'notebook',
#   'folder',
#   'set',
#   'colored',
#   'pencil',
#   'set',
#   'marker',
#   'pencil',
#   'safe',
#   'scissor',
#   'glue'],
#  ['help', 'student', 'engage', 'manipulative', 'love', 'math', 'center'],
#  ['help',
#   'student',
#   'novel',
#   'represent',
#   'diversity',
#   'exist',
#   'world',
#   'expensive',
#   'book',
#   'lgbtq',
#   'fiction',
#   'nonfiction',
#   'civil',
#   'right',
#   'rest',
#   'represent',
#   'diversity'],
#  ['help',
#   'student',
#   'way',
#   'engage',
#   'hand',
#   'activity',
#   'teach',
#   'century',
#   'skill'],
#  ['help',
#   'student',
#   'book',
#   'teach',
#   'race',
#   'inequality',
#   'privilege',
#   'unite'],
#  ['help', 'student', 'new', 'rocker', 'chair', 'match', 'stool', 'classroom'],
#  ['help', 'student', 'tool', 'need', 'publish', 'writing'],
#  ['help', 'student', 'clay', 'slab', 'roller', 'grow', 'ceramic', 'program'],
#  ['help',
#   'student',
#   'brand',
#   'new',
#   'spectacular',
#   'magical',
#   'multicultural',
#   'literature',
#   'library'],
#  ['help',
#   'student',
#   'time',
#   'kid',
#   'map',
#   'skill',
#   'today',
#   'magazine',
#   'learn',
#   'world'],
#  ['help',
#   'student',
#   'high',
#   'interest',
#   'exciting',
#   'book',
#   'promote',
#   'love',
#   'reading',
#   'high_interest'],
#  ['help',
#   'student',
#   'ergonomic',
#   'study',
#   'space',
#   'laptop',
#   'stand',
#   'wireless',
#   'keyboard',
#   'mouse',
#   'combo',
#   'keyboard',
#   'wrist',
#   'rest',
#   'pad',
#   'home',
#   'covid',
#   'crisis'],
#  ['student',
#   'need',
#   'ipad',
#   'protective',
#   'case',
#   'create',
#   'digital',
#   'portfolio',
#   'explore',
#   'artwork',
#   'enhance',
#   'learn',
#   'utilize',
#   'change',
#   'need',
#   'century',
#   'society'],
#  ['help', 'student', 'choice', 'book', 'home', 'read', 'summer'],
#  ['help',
#   'student',
#   'variety',
#   'item',
#   'order',
#   'explore',
#   'learn',
#   'science',
#   'different',
#   'science',
#   'technology',
#   'engineering',
#   'music',
#   'activity'],
#  ['help',
#   'student',
#   'receive',
#   'enrich',
#   'activity',
#   'hand',
#   'math',
#   'concept',
#   'age',
#   'appropriate',
#   'sensory',
#   'material',
#   'explore',
#   'eager',
#   'learning',
#   'scholar'],
#  ['help',
#   'student',
#   'ipad',
#   'bundle',
#   'access',
#   'support',
#   'learn',
#   'math',
#   'science',
#   'english'],
#  ['help',
#   'student',
#   'chromebook',
#   'practice',
#   'literacy',
#   'skill',
#   'independently'],
#  ['help',
#   'student',
#   'variety',
#   'writing',
#   'tool',
#   'help',
#   'remote',
#   'learning',
#   'give',
#   'creative',
#   'outlet',
#   'way',
#   'practice',
#   'writing',
#   'letter',
#   'number',
#   'strengthen',
#   'fine',
#   'motor',
#   'skill',
#   'remote_learning'],
#  ['help',
#   'student',
#   'stem',
#   'activity',
#   'home',
#   'check',
#   'school',
#   'epidemic'],
#  ['help', 'student', 'basic', 'need', 'enjoy', 'paint', 'home'],
#  ['help',
#   'student',
#   'marker',
#   'color',
#   'book',
#   'busy',
#   'pandemic',
#   'let',
#   'fun',
#   'coloring'],
#  ['help',
#   'student',
#   'osmo',
#   'technology',
#   'stem',
#   'kit',
#   'engage',
#   'learning'],
#  ['help', 'student', 'flexible', 'seat', 'learn', 'science', 'steam', 'room'],
#  ['help',
#   'student',
#   'teacher',
#   'pay',
#   'teacher',
#   'gift',
#   'card',
#   'purchase',
#   'distance',
#   'learning',
#   'resource',
#   'distance_learning'],
#  ['help',
#   'student',
#   'performance',
#   'essential',
#   'like',
#   'guitar',
#   'string',
#   'cable',
#   'pick'],
#  ['help',
#   'student',
#   'topcase',
#   'rubberize',
#   'black',
#   'hard',
#   'case',
#   'cover',
#   'macbook',
#   'white',
#   'mosiso',
#   'plastic',
#   'hard',
#   'shell',
#   'case',
#   'keyboard',
#   'cover',
#   'screen',
#   'protector',
#   'compatible',
#   'old',
#   'version',
#   'macbook',
#   'pro',
#   'inch'],
#  ['help',
#   'student',
#   'suffer',
#   'trauma',
#   'new',
#   'way',
#   'work',
#   'trauma',
#   'resilient',
#   'thrive',
#   'tool',
#   'request',
#   'allow',
#   'student',
#   'play',
#   'process',
#   'experience'],
#  ['help',
#   'student',
#   'time',
#   'kid',
#   'scholastic',
#   'news',
#   'access',
#   'informational',
#   'article',
#   'world',
#   'live'],
#  ['help',
#   'student',
#   'lego',
#   'set',
#   'entertain',
#   'learn',
#   'stay',
#   'safe',
#   'home'],
#  ['help',
#   'student',
#   'backpack',
#   'school',
#   'supply',
#   'earbud',
#   'bluetooth',
#   'speaker',
#   'aid',
#   'kit',
#   'portable',
#   'charger',
#   'toiletry',
#   'college'],
#  ['help',
#   'student',
#   'book',
#   'connect',
#   'racial',
#   'injustice',
#   'life',
#   'path',
#   'forward',
#   'provide',
#   'idea',
#   'confront',
#   'challenge',
#   'conspirator',
#   'ally',
#   'hopeful',
#   'share',
#   'future'],
#  ['help',
#   'student',
#   'access',
#   'instruction',
#   'allow',
#   'demonstrate',
#   'geometry',
#   'poster',
#   'board',
#   'dry',
#   'erase',
#   'board',
#   'print',
#   'practice',
#   'laminate',
#   'wipe',
#   'dry_erase'],
#  ['help',
#   'student',
#   'science',
#   'stem',
#   'related',
#   'board',
#   'game',
#   'navigate',
#   'distance',
#   'learning',
#   'summer',
#   'school',
#   'distance_learning'],
#  ['help', 'student', 'copy', 'fabulous', 'life', 'change', 'book'],
#  ['help',
#   'student',
#   'opportunity',
#   'practice',
#   'real',
#   'world',
#   'skill',
#   'dramatic',
#   'play'],
#  ['help', 'student', 'colored', 'copy', 'gift', 'colored', 'printer'],
#  ['help',
#   'student',
#   'technology',
#   'reach',
#   'potential',
#   'instruction',
#   'meet',
#   'individual',
#   'need'],
#  ['help',
#   'student',
#   'essential',
#   'material',
#   'learn',
#   'home',
#   'way',
#   'developmentally',
#   'appropriate'],
#  ['help',
#   'student',
#   'opportunity',
#   'career',
#   'exploration',
#   'visit',
#   'potential',
#   'job',
#   'sight'],
#  ['help',
#   'student',
#   'headphone',
#   'work',
#   'creative',
#   'assignment',
#   'computer',
#   'lab',
#   'day'],
#  ['help',
#   'student',
#   'attractivia',
#   'magnetic',
#   'number',
#   'flash',
#   'card',
#   'large',
#   'number',
#   'card',
#   'addition',
#   'subtraction',
#   'multiplication',
#   'division',
#   'symbol',
#   'live',
#   'online',
#   'learning',
#   'summer'],
#  ['help',
#   'student',
#   'care',
#   'package',
#   'include',
#   'snack',
#   'paper',
#   'towel',
#   'tissue',
#   'new',
#   'shirt',
#   'new',
#   'pencil'],
#  ['help',
#   'student',
#   'equipment',
#   'drum',
#   'line',
#   'bass',
#   'drum',
#   'snare',
#   'drum',
#   'harness',
#   'essential',
#   'field',
#   'percussion',
#   'player'],
#  ['help',
#   'student',
#   'workbench',
#   'table',
#   'double',
#   'student',
#   'desk',
#   'area'],
#  ['help',
#   'student',
#   'marker',
#   'dry',
#   'erase',
#   'board',
#   'craft',
#   'school',
#   'tool',
#   'need',
#   'thrive',
#   'home',
#   'dry_erase'],
#  ['help',
#   'student',
#   'elmo',
#   'enhance',
#   'lesson',
#   'interaction',
#   'aide',
#   'ability',
#   'stay',
#   'focused'],
#  ['help',
#   'student',
#   'kind',
#   'hand',
#   'learn',
#   'experience',
#   'spark',
#   'love',
#   'learning'],
#  ['help',
#   'student',
#   'pretend',
#   'play',
#   'market',
#   'craft',
#   'supply',
#   'provide',
#   'introduction',
#   'fiscally',
#   'responsible',
#   'like',
#   'use',
#   'supply',
#   'teach',
#   'student',
#   'financial',
#   'literacy',
#   'read',
#   'let',
#   'sell',
#   'item',
#   'spend',
#   'income'],
#  ['help',
#   'student',
#   'book',
#   'classroom',
#   'library',
#   'guide',
#   'reading',
#   'group',
#   'classroom_library'],
#  ['help',
#   'student',
#   'classroom',
#   'quality',
#   'document',
#   'camera',
# ...
#   'fill',
#   'home',
#   'learning',
#   'bag',
#   'necessary',
#   'material',
#   'send',
#   'directly',
#   'student',
#   'home'],
#  ['help',
#   'student',
#   'lego',
#   'mindstorm',
#   'education',
#   'core',
#   'set',
#   'provide',
#   'opportunity',
#   'combine',
#   'love',
#   'lego',
#   'robot',
#   'learn',
#   'computer',
#   'programming'],
#  ['help',
#   'student',
#   'teacher',
#   'pay',
#   'teacher',
#   'gift',
#   'card',
#   'vinyl',
#   'sheet',
#   'pencil',
#   'sharpener',
#   'marker',
#   'material',
#   'encouragement',
#   'continue',
#   'work',
#   'home',
#   'supply',
#   'need',
#   'teach'],
#  ['help', 'student', 'book', 'diverse', 'unique', 'like'],
#  ['help',
#   'student',
#   'magna',
#   'tile',
#   'snowflake',
#   'playstix',
#   'gear',
#   'builder',
#   'soft',
#   'start',
#   'school',
#   'day'],
#  ['help',
#   'student',
#   'math',
#   'manipulative',
#   'math',
#   'game',
#   'hand',
#   'learn',
#   'experience'],
#  ['help',
#   'student',
#   'specifically',
#   'female',
#   'opportunity',
#   'healthy',
#   'clean'],
#  ['help',
#   'student',
#   'color',
#   'canon',
#   'printer',
#   'visual',
#   'aid',
#   'real',
#   'photo'],
#  ['help',
#   'student',
#   'table',
#   'stool',
#   'use',
#   'small',
#   'group',
#   'collaborative',
#   'project'],
#  ['help', 'student', 'ability', 'acquire', 'fundamental', 'culinary', 'art'],
#  ['help', 'student', 'book', 'home', 'independent', 'reading'],
#  ['help',
#   'student',
#   'laminate',
#   'machine',
#   'laminating',
#   'sheet',
#   'enhance',
#   'distance',
#   'learning',
#   'distance_learning'],
#  ['help',
#   'student',
#   'material',
#   'teacher',
#   'pay',
#   'teacher',
#   'gift',
#   'card',
#   'resource',
#   'learn',
#   'need',
#   'pandemic'],
#  ['help',
#   'student',
#   'chromebook',
#   'use',
#   '-pron-',
#   'get',
#   'fix',
#   'school',
#   'district'],
#  ['help', 'student', 'costume', 'set', 'prop', 'piece', 'need', 'hit'],
#  ['help',
#   'student',
#   'new',
#   'type',
#   'book',
#   'library',
#   'like',
#   'graphic',
#   'novel',
#   'introduce',
#   'new',
#   'upcoming',
#   'author'],
#  ['help',
#   'student',
#   'material',
#   'need',
#   'successful',
#   'learner',
#   'home',
#   'provide',
#   'physical',
#   'resource',
#   'young',
#   'child',
#   'need',
#   'stay',
#   'engaged',
#   'learning'],
#  ['help',
#   'student',
#   'personalize',
#   'resource',
#   'supply',
#   'postage',
#   'stamp',
#   'mail',
#   'package',
#   'note',
#   'distance',
#   'learning',
#   'last',
#   'distance_learning'],
#  ['help',
#   'student',
#   'new',
#   'game',
#   'play',
#   'help',
#   'reinforce',
#   'important',
#   'math',
#   'skill',
#   'learn',
#   'math',
#   'fun'],
#  ['help',
#   'student',
#   'opportunity',
#   'better',
#   'communicate',
#   'creative',
#   'fun',
#   'easy',
#   'way',
#   'pandemic'],
#  ['help',
#   'student',
#   'great',
#   'literacy',
#   'foundation',
#   'sensory',
#   'opportunity'],
#  ['help',
#   'student',
#   'power',
#   'need',
#   'use',
#   'keyboard',
#   'miss',
#   'power',
#   'cord',
#   'need',
#   'mallet',
#   'xylophone'],
#  ['help',
#   'student',
#   'chrome',
#   'book',
#   'chrome',
#   'book',
#   'help',
#   'build',
#   'need',
#   'computer',
#   'literacy',
#   'skill',
#   'student'],
#  ['help',
#   'student',
#   'basic',
#   'chromebook',
#   'laptop',
#   'create',
#   'image',
#   'digital',
#   'artwork',
#   'histree',
#   'project',
#   'visual',
#   'installation',
#   'history',
#   'headquarters',
#   'student',
#   'research',
#   'great',
#   'art',
#   'visual',
#   'online'],
#  ['help',
#   'student',
#   'type',
#   'quality',
#   'lesson',
#   'follow',
#   'social',
#   'distancing',
#   'guideline'],
#  ['help',
#   'student',
#   'listen',
#   'center',
#   'classroom',
#   'library',
#   'help',
#   'grow',
#   'prereading',
#   'skill',
#   'classroom_library'],
#  ['help', 'student', 'supply', 'material', 'need', 'succeed'],
#  ['help',
#   'student',
#   'new',
#   'headphone',
#   'better',
#   'utilize',
#   'laptop',
#   'microphone',
#   'help',
#   'speak',
#   'better'],
#  ['help',
#   'student',
#   'desk',
#   'organizer',
#   'bulletin',
#   'board',
#   'paper',
#   'tea',
#   'holiday',
#   'mint'],
#  ['help',
#   'student',
#   'accessible',
#   'material',
#   'explore',
#   'life',
#   'science',
#   'way'],
#  ['help',
#   'student',
#   'boomwhacker',
#   'tune',
#   'percussion',
#   'tube',
#   'create',
#   'important',
#   'opportunity',
#   'hand',
#   'learn',
#   'music',
#   'greatly',
#   'expand',
#   'student',
#   'practical',
#   'knowledge',
#   'basic',
#   'musical',
#   'skill'],
#  ['help',
#   'student',
#   'individual',
#   'drawer',
#   'hold',
#   'material',
#   'school',
#   'day'],
#  ['help', 'student', 'book', 'life', 'work', 'legendary', 'musician'],
#  ['help',
#   'student',
#   'basic',
#   'necessity',
#   'include',
#   'sofa',
#   'hoodie',
#   'supply',
#   'need',
#   'experience',
#   'success',
#   'feel',
#   'comfortable',
#   'academic',
#   'environment'],
#  ['help', 'student', 'new', 'supply', 'distant', 'learning', 'activity'],
#  ['help',
#   'student',
#   'stem',
#   'exploration',
#   'build',
#   'set',
#   'help',
#   'design',
#   'create',
#   'roller',
#   'coaster',
#   'bridge',
#   'building',
#   'project',
#   'home',
#   'present',
#   'virtually',
#   'peer',
#   'student',
#   'stem',
#   'kit'],
#  ['help', 'student', 'positive', 'school', 'surprise', 'care', 'package'],
#  ['help',
#   'student',
#   'electronic',
#   'pen',
#   'tablet',
#   'microphone',
#   'record',
#   'instructional',
#   'video'],
#  ['help', 'student', 'laptop', 'learn', 'health', 'class'],
#  ['help',
#   'student',
#   'timeline',
#   'seuss',
#   'book',
#   'book',
#   'miss',
#   'seus',
#   'collection',
#   'allow',
#   'timeline',
#   'seuss',
#   'book',
#   'actual',
#   'book'],
#  ['help', 'student', 'flexible', 'seat', 'focused', 'engage'],
#  ['help',
#   'student',
#   'pre',
#   'vocational',
#   'work',
#   'skill',
#   'life',
#   'high',
#   'school',
#   'nasco',
#   'pre',
#   'vocational',
#   'work',
#   'skill',
#   'complete',
#   'set'],
#  ['help',
#   'student',
#   'book',
#   'rest',
#   'school',
#   'year',
#   'help',
#   'student',
#   'grow',
#   'love',
#   'learn',
#   'book',
#   'funny',
#   'accessible',
#   'old',
#   'favorite',
#   'school_year'],
#  ['help',
#   'student',
#   'access',
#   'modern',
#   'text',
#   'today',
#   'society',
#   'bryan',
#   'stevenson',
#   'mercy'],
#  ['help',
#   'student',
#   'accessibility',
#   'material',
#   'individually',
#   'appropriate',
#   'remote',
#   'learning',
#   'send',
#   'visual',
#   'schedule',
#   'board',
#   'worksheet',
#   'week',
#   'able',
#   'complete',
#   'work',
#   'remote_learning'],
#  ['help',
#   'student',
#   'tabletop',
#   'write',
#   'center',
#   'help',
#   'develop',
#   'great',
#   'writing',
#   'habit'],
#  ['help', 'student', 'literature', 'deserve', 'fingertip'],
#  ['help',
#   'student',
#   'flexible',
#   'seat',
#   'choice',
#   'work',
#   'comfortably',
#   'classroom'],
#  ['help',
#   'student',
#   'fiction',
#   'nonfiction',
#   'book',
#   'help',
#   'classroom',
#   'library',
#   'grow',
#   'classroom_library'],
#  ['help',
#   'student',
#   'book',
#   'classroom',
#   'library',
#   'read',
#   'read',
#   'classroom_library'],
#  ['help',
#   'student',
#   'learn',
#   'livelihood',
#   'entrepreneurship',
#   'skill',
#   'help',
#   'high',
#   'school'],
#  ['student',
#   'need',
#   'lcd',
#   'write',
#   'tablet',
#   'use',
#   'practice',
#   'example',
#   'brainstorm',
#   'idea',
#   'real',
#   'life',
#   'application'],
#  ['help', 'student', 'comfortable', 'homey', 'space', 'rug'],
#  ['help', 'student', 'access', 'variety', 'story', 'open', 'imagination'],
#  ['help', 'student', 'instrument', 'create', 'sing', 'song'],
#  ['help',
#   'student',
#   'differentiate',
#   'learn',
#   'material',
#   'activity',
#   'meet',
#   'iep',
#   'goal',
#   'teacher',
#   'pay',
#   'teacher',
#   'resource'],
#  ['help',
#   'student',
#   'engage',
#   'resource',
#   'touch',
#   'read',
#   'phonic',
#   'sentence',
#   'match',
#   'writing',
#   'tablet',
#   'word',
#   'family',
#   'card',
#   'help',
#   'lay',
#   'foundation',
#   'literate',
#   'life'],
#  ['help',
#   'student',
#   'good',
#   'cultural',
#   'reading',
#   'experience',
#   'second',
#   'grade'],
#  ['help', 'student', 'book', 'continue', 'read', 'school', 'library', 'close'],
#  ['help', 'student', 'book', 'continue', 'read', 'school', 'library', 'close'],
#  ['help',
#   'student',
#   'hygiene',
#   'product',
#   'like',
#   'hand',
#   'sanitizer',
#   'shampoo',
#   'hand',
#   'soap'],
#  ['help',
#   'student',
#   'diverse',
#   'book',
#   'continue',
#   'read',
#   'library',
#   'close'],
#  ['help',
#   'student',
#   'flexible',
#   'seating',
#   'wobble',
#   'cushion',
#   'balance',
#   'ball',
#   'support',
#   'diverse',
#   'learning',
#   'style',
#   'flexible_seating'],
#  ['help',
#   'student',
#   'diverse',
#   'book',
#   'continue',
#   'read',
#   'library',
#   'close'],
#  ['help',
#   'student',
#   'seamless',
#   'distance',
#   'learning',
#   'classroom',
#   'love',
#   'distance_learning'],
#  ['help', 'student', 'stem', 'material', 'allow', 'learn', 'hand', 'play'],
#  ['help',
#   'student',
#   'diverse',
#   'book',
#   'continue',
#   'read',
#   'library',
#   'close'],
#  ['help',
#   'student',
#   'book',
#   'continue',
#   'learn',
#   'book',
#   'literature',
#   'circle',
#   'independent',
#   'reading',
#   'time'],
#  ['help',
#   'student',
#   'exposure',
#   'anti',
#   'racist',
#   'multi',
#   'cultural',
#   'book',
#   'teach',
#   'cultural',
#   'competency'],
#  ['help',
#   'student',
#   'resource',
#   'learning',
#   'home',
#   'book',
#   'workbook',
#   'activity',
#   'supply',
#   'like',
#   'crayon',
#   'pencil',
#   'glue'],
#  ['help',
#   'student',
#   'jump',
#   'start',
#   'century',
#   'learn',
#   'apple',
#   'ipad',
#   'printer'],
#  ['help',
#   'student',
#   'new',
#   'habitat',
#   'classroom',
#   'guinea',
#   'pig',
#   'watch',
#   'explore',
#   'grow'],
#  ['help', 'student', 'graduation', 'bag', 'fill', 'special', 'message'],
#  ['help',
#   'student',
#   'hand',
#   'material',
#   'need',
#   'learn',
#   'recognition',
#   'formation',
#   'uppercase',
#   'lowercase',
#   'letter'],
#  ['help',
#   'student',
#   'set',
#   'literature',
#   'year',
#   'camping',
#   'theme',
#   'allow',
#   'study',
#   'environment',
#   'geography',
#   'historical',
#   'site',
#   'steam',
#   'lesson',
#   'map',
#   'exciting',
#   'way',
#   'combine',
#   'lesson'],
#  ['help',
#   'student',
#   'copy',
#   'frankenstein',
#   'mary',
#   'shelly',
#   'copy',
#   'raisin',
#   'sun',
#   'lorraine',
#   'hansberry',
#   'teach',
#   'book'],
#  ['help',
#   'student',
#   'resource',
#   'need',
#   'master',
#   'middle',
#   'school',
#   'science',
#   'social',
#   'study',
#   'especially',
#   'need',
#   'know',
#   'book'],
#  ['help',
#   'student',
#   'access',
#   'home',
#   'dry',
#   'erase',
#   'board',
#   'cupboards',
#   'marker',
#   'book',
#   'dry_erase'],
#  ['help',
#   'student',
#   'opportunity',
#   'grow',
#   'critical',
#   'thinking',
#   'skill',
#   'cooperative',
#   'learn',
#   'stem',
#   'bin'],
#  ['help',
#   'student',
#   'big',
#   'joe',
#   'bean',
#   'bag',
#   'chair',
#   'flexible',
#   'seating',
#   'option',
#   'classroom',
#   'flexible_seating'],
#  ['help',
#   'student',
#   'book',
#   'fill',
#   'gap',
#   'library',
#   'select',
#   'new',
#   'title',
#   'engaging',
#   'title',
#   'miss',
#   'series',
#   'book'],
#  ['help',
#   'student',
#   'activity',
#   'help',
#   'support',
#   'remote',
#   'learning',
#   'engage',
#   'help',
#   'support',
#   'mastery',
#   'necessary',
#   'skill',
#   'remote_learning'],
#  ['help', 'student', 'copy', 'book', 'worm'],
#  ['help',
#   'student',
#   'tool',
#   'support',
#   'storytelling',
#   'skill',
#   'story',
#   'grammar',
#   'marker',
#   'story',
#   'champ',
#   'interactive',
#   'support',
#   'design',
#   'guide',
#   'student',
#   'identify',
#   'retell',
#   'important',
#   'part',
#   'narrative'],
#  ['help', 'student', 'great', 'start', 'new', 'school', 'year', 'school_year'],
#  ['help', 'student', 'book', 'student', 'home', 'little', 'book'],
#  ['help',
#   'student',
#   'variety',
#   'material',
#   'inside',
#   'recess',
#   'child',
#   'grade',
#   'love',
#   'build',
#   'material',
#   'allow',
#   'rainy',
#   'day',
#   'grader',
#   'love',
#   'skymag',
#   'magnetic',
#   'block'],
#  ['help', 'student', 'touch', 'school', 'help', 'learn', 'home'],
#  ['help',
#   'student',
#   'resource',
#   'college',
#   'life',
#   'include',
#   'laptop',
#   'portable',
#   'charger',
#   'external',
#   'hard',
#   'drive',
#   'power',
#   'bank',
#   'go'],
#  ['help', 'student', 'ink', 'cartridge', 'new', 'laser', 'jet', 'printer'],
#  ['help',
#   'student',
#   'kid',
#   'coding',
#   'robotic',
#   'kit',
#   'learn',
#   'century',
#   'technology',
#   'skill'],
#  ['help',
#   'student',
#   'basic',
#   'school',
#   'supply',
#   'help',
#   'learn',
#   'mind',
#   'active',
#   'covid',
#   'pandemic'],
#  ['help',
#   'student',
#   'sensory',
#   'toy',
#   'allow',
#   'explore',
#   'key',
#   'learning',
#   'target',
#   'light',
#   'table',
#   'provide',
#   'student',
#   'need',
#   'sensory',
#   'play',
#   'enhance',
#   'literacy',
#   'math',
#   'skill'],
#  ['help', 'student', 'school', 'camping', 'theme', 'forget'],
#  ['help',
#   'student',
#   'supply',
#   'need',
#   'kindergarten',
#   'year',
#   'healthy',
#   'successful'],
#  ['help',
#   'student',
#   'listen',
#   'center',
#   'activity',
#   'strengthen',
#   'phonemic',
#   'awareness',
#   'skill'],
#  ['help',
#   'student',
#   'ipad',
#   'pro',
#   'create',
#   'video',
#   'content',
#   'learn',
#   'creative',
#   'software'],
#  ['help',
#   'student',
#   'headphone',
#   'splitter',
#   'group',
#   'blend',
#   'learning',
#   'lesson',
#   'power',
#   'strip',
#   'tower',
#   'charge',
#   'tablet',
#   'wireless',
#   'keyboard'],
#  ['help',
#   'student',
#   'sphero',
#   'learn',
#   'programming',
#   'collaboration',
#   'express',
#   'creativity',
#   'think',
#   'critically',
#   'skill',
#   'critical',
#   'success',
#   'school',
#   'class'],
#  ['help', 'student', 'informational', 'text', 'teach', 'climate', 'change'],
#  ['help',
#   'student',
#   'surprise',
#   'letter',
#   'mail',
#   'excited',
#   'card',
#   'stamp',
#   'perfect'],
#  ['help',
#   'student',
#   'retractable',
#   'mouse',
#   'help',
#   'testing',
#   'computer',
#   'little',
#   'easy'],
#  ['help',
#   'student',
#   'art',
#   'easel',
#   'explore',
#   'visual',
#   'art',
#   'express',
#   'idea'],
#  ['help',
#   'student',
#   'flexible',
#   'seating',
#   'option',
#   'classroom',
#   'floor',
#   'table',
#   'flexible_seating'],
#  ['help',
#   'student',
#   'twist',
#   'turn',
#   'word',
#   'builder',
#   'storyteller',
#   'write',
#   'box',
#   'teacher',
#   'pay',
#   'teacher',
#   'card',
#   'purchase',
#   'ela',
#   'resource',
#   'help',
#   'literacy',
#   'writing'],
#  ['help', 'student', 'voice', 'people', 'impact', 'life'],
#  ['help',
#   'student',
#   'sphero',
#   'specdrum',
#   'new',
#   'makerspace',
#   'station',
#   'combine',
#   'music',
#   'coding'],
#  ['help', 'student', 'book', 'interested', 'reading', 'reflect', 'people'],
#  ['help',
#   'student',
#   'supply',
#   'need',
#   'hand',
#   'geography',
#   'activity',
#   'reuse',
#   'year',
#   'come'],
#  ['help',
#   'student',
#   'artista',
#   'pottery',
#   'wheel',
#   'continue',
#   'education',
#   'home',
#   'clay',
#   'surface',
#   'application',
#   'like',
#   'underglaze',
#   'apply',
#   'wheel',
#   'thrown',
#   'tile',
#   'test',
#   'conduct',
#   'tile'],
#  ['help', 'student', 'book', 'continue', 'grow', 'love', 'read'],
#  ['help', 'student', 'handheld', 'lamp', 'glogerm', 'handwashing', 'activity'],
#  ['help',
#   'student',
#   'essential',
#   'assignment',
#   'supply',
#   'send',
#   'student',
#   'organize',
#   'prepare',
#   'learn',
#   'home'],
#  ['help',
#   'student',
#   'book',
#   'encourage',
#   'social',
#   'emotional',
#   'learning',
#   'cultural',
#   'relevance',
#   'social_emotional'],
#  ['help',
#   'student',
#   'paint',
#   'material',
#   'use',
#   'kit',
#   'check',
#   'distance',
#   'learning',
#   'clean',
#   'class',
#   'safe',
#   'virus',
#   'school',
#   'distance_learning'],
#  ['help',
#   'student',
#   'webcam',
#   'communication',
#   'distance',
#   'learning',
#   'conferencing',
#   'distance_learning'],
#  ['help',
#   'student',
#   'opportunity',
#   'enhance',
#   'learning',
#   'use',
#   'technology',
#   'classroom',
#   'ipad',
#   'student',
#   'able',
#   'use',
#   'app',
#   'website',
#   'hand',
#   'method',
#   'learning'],
#  ['help',
#   'student',
#   'soccer',
#   'ball',
#   'middle',
#   'school',
#   'inflate',
#   'ball',
#   'pump',
#   'boy',
#   'locker',
#   'room',
#   'set',
#   'dodgeball',
#   'color',
#   'cone',
#   'famous',
#   'capture',
#   'cone',
#   'game'],
#  ['help',
#   'student',
#   'gift',
#   'read',
#   'amazing',
#   'novel',
#   'learn',
#   'lifelong',
#   'lesson',
#   'kindness'],
#  ['help',
#   'student',
#   'research',
#   'base',
#   'phonological',
#   'awareness',
#   'phonic',
#   'sight',
#   'word',
#   'base',
#   'intervention',
#   'program',
#   'assist',
#   'student',
#   'successful',
#   'reader',
#   'writer'],
#  ['help',
#   'student',
#   'culturally',
#   'responsive',
#   'book',
#   'help',
#   'learn',
#   'stand',
#   'racism',
#   'injustice'],
#  ['help', 'student', 'google', 'pixelbook', 'chromebook', 'touch', 'screen'],
#  ...]

# %% [markdown]
# Looping through all texts, let's save the most likely topic number.

# %%
docs[0]
# Out:
# ['help',
#  'student',
#  'summer',
#  'reading',
#  'boost',
#  'engaging',
#  'digital',
#  'reading',
#  'program']

# %%
texts[0]
# Out:
# 'help me give my students a summer reading boost with a very engaging digital reading program'

# %%
topic_nums = []
for (text, doc) in zip(texts, docs):
    probs = np.array(model[dictionary.doc2bow(doc)])
    topic_nums.append(probs[np.argsort(probs[:,-1])][-1,0])
    
data['topic'] = topic_nums

product_vs_topic = pd.crosstab(data['id'], data['topic'])
product_vs_topic = product_vs_topic.T / product_vs_topic.sum(axis = 1) * 100
product_vs_topic = product_vs_topic.T

# %%
pd.set_option('display.max_columns', None)
#pd.set_option("max_rows", None) #undo by resetting --- 
#pd.reset_option("display.max_rows")
#pd.set_option('display.max_rows', 500)
pd.set_option('display.max_rows', 50)

# %%
data.head()
# Out:
#         id  \
# 0  4956615
# 1  4904116
# 2  4333875
# 3  4948217
# 4  4946464
#
#                                                                                                                                                        text
# 0                                                              help me give my students a summer reading boost with a very engaging digital reading program
# 1               help me give my students various dice and a starting dice game to use in endless ways at home to practice reinforce and learn math concepts
# 2                                      help me give my students a safe welcoming comfortable classroom space where they can feel at home and ready to learn
# 3              help me give my students basic school supplies every child needs a pencil and now even disinfectant wipes to keep everyone safe and learning
# 4  help me give my students the hands on materials they need during remote learning i have included hands on materials as well as a math workbook and snack

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

product_vs_topic.round(2).style.apply(background_gradient,
               cmap='YlGnBu',
               m=product_vs_topic.min().min(),
               M=product_vs_topic.max().max(),
               low=0.5,
               high=0.8)
# Out:
# <style  type="text/css" >
#     #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row0_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row0_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row0_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row0_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row0_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row0_col5 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row1_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row1_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row1_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row1_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row1_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row1_col5 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row2_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row2_col1 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row2_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row2_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row2_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row2_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row3_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row3_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row3_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row3_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row3_col4 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row3_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row4_col0 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row4_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row4_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row4_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row4_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row4_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row5_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row5_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row5_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row5_col3 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row5_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row5_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row6_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row6_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row6_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row6_col3 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row6_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row6_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row7_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row7_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row7_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row7_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row7_col4 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row7_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row8_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row8_col1 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row8_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row8_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row8_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row8_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row9_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row9_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row9_col2 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row9_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row9_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row9_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row10_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row10_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row10_col2 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row10_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row10_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row10_col5 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row11_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row11_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row11_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row11_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row11_col4 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row11_col5 {
#             background-color:  #1e86bb;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row12_col0 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row12_col1 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row12_col2 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row12_col3 {
#             background-color:  #d1edb3;
#         }    #T_ad29a6d0_a69c_11ea_ab6b_c520ca2bba65row12_col4

# %%
data.loc[data['id'].isin(['4957430','4957502','4957562'])]
# Out:
#           id  \
# 70   4957562
# 262  4957502
# 287  4957430
#
#                                                                                                                text  \
# 70                            help me give my students books that showcase diversity and inclusion in our classroom
# 262   help me give my students books featuring diverse characters that reflect the diverse population of our school
# 287  help me give my students stories that create more representation with characters from marginalized backgrounds
#
#      topic
# 70     4.0
# 262    4.0
# 287    4.0

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Many collections of unstructured texts don't come with any labels. Topic models such as Latent Dirichlet Allocation are a useful technique to discover the most prominent topics in such documents. Gensim makes training these topics model easy, and pyLDAvis presents the results in a visually attractive way. Together they form a powerful toolkit to better understand what's inside large sets of documents and to explore subsets of related texts. However, these methods can perform poorly in short texts with vague or unspecified subjects. Although traditional topic models are lacking in more semantic information (they don't use word embeddings, for instance), they can be really quick way of getting insights into large collections of documents.

# %% [markdown]
# # An Introduction to Word Embeddings

# %% [markdown]
# One of the breakthroughs in Natural Language Processing is the usage of word embeddings. Rather than using the words themselves as features, neural network methods typically take as input dense, relatively low-dimensional vectors that model the meaning and usage of a word. Word embeddings were first popularized through the [Word2Vec](https://arxiv.org/abs/1301.3781) model, developed by Thomas Mikolov and colleagues at Google. Since then, scores of alternative approaches have been developed, such as [GloVe](https://nlp.stanford.edu/projects/glove/) and [FastText](https://fasttext.cc/) embeddings. In this notebook, we'll explore word embeddings with the original Word2Vec approach, as implemented in the [Gensim](https://radimrehurek.com/gensim/) library.
#
# Modified from: https://github.com/nlptown/nlp-notebooks/blob/master/An%20Introduction%20to%20Word%20Embeddings.ipynb

# %% [markdown]
# ## Training word embeddings

# %% [markdown]
# To train word embedings, we need to compile a corpus of text that captures the meaning and usage of words in a particular dialect. Wikipedia is a good choice for training generic embeddings representing the proper use of different languages. For our experiments, however, we're going to use scraped comments from [r/aww](https://www.reddit.com/r/aww/), a subreddit of "Things that make you go AWW! Like puppies, bunnies, babies and so on".
#
# We've collected and lowercased a collection of 6 months of comments from this subreddit using the scripts in the notebook `0.Data Scraping and Prep`.
#
# Each entry in this file represents one comment in one post from that subreddit.

# %%
import pickle #for saving output files, pickles
import pandas as pd

#read in 'cleantrailer.pickle' from 'trailer_cleaning_inspection.ipynb'
with open('/home/russell/Documents/DataScience/DonorsChoose/Data/cleantrailer.pickle', 'rb') as handle:
    trailers = pickle.load(handle)

# %%
# import os
# import warnings
# warnings.filterwarnings("ignore")

# class SentenceCorpus(object):

#     def __init__(self, filename):
#         self.filename = filename

#     def __iter__(self):
#         with open(self.filename, "r") as i:
#             for line in i:
#                 tokens = line.strip().split()
#                 yield tokens

                
# # This command will unzip the text file
# # The rest of the cell will run even if this command fails
# #!gzip -d ../data/reddit_aww_comments.csv.gz
                
# TEXT_FILE = '/home/russell/Documents/DataScience/DonorsChoose/Data/trailers.csv'
# sentences = SentenceCorpus(TEXT_FILE)
# #sentences = (data['trailer'])

# %%
# import string

# ref_table = str.maketrans('', '', string.punctuation)
# sents = pd.read_csv(TEXT_FILE)

# sent_toks = []
# for s in range(len(sents.iloc[:,0])):
#     # split into words by white space
#     words = sents['trailer'][s].split()
#     #remove punctuation from each word
#     stripped = [w.translate(ref_table) for w in words]
#     sent_toks.append(stripped)
    
# sentences = sent_toks

# %%
sentences = trailers

# %% [markdown]
# When training word embeddings, Gensim allows the user to set a number of parameters. The most important are:
#
# - `min_count` is the **minimum frequency of the words** in our corpus. For infrequent words, we just don't have enough information to train reliable word embeddings. It therefore makes sense to set this minimum frequency to at least 10.
#
#
# - `window` is **number of words to the left and to the right that make up the context for the word** that word2vec will take into account.
#
#
# - `size` is the **dimensionality of the word vectors**. This is generally between 100 and 1000. You often have to make a trade-off: embeddings with a higher dimensionality are able to model more information, but also need more data to train.
#
#
# - `sg`: there are two **algorithms to train word2vec**: skip-gram and CBOW. Skip-gram tries to predict the context on the basis of the target word; CBOW tries to find the target on the basis of the context. By default, Gensim uses CBOW (`sg=0`).

# %%
import gensim
model = gensim.models.Word2Vec(sentences, min_count=10, window=3, size=100)

# %%
sentences[0]
# Out:
# ['help',
#  'student',
#  'summer',
#  'reading',
#  'boost',
#  'engaging',
#  'digital',
#  'reading',
#  'program']

# %% [markdown]
# ## Using word embeddings

# %% [markdown]
# Let's take a look at the model. The word embeddings are on the `wv` attribute of the model. We can access them by the using the token as key. The vocabulary includes any token that occurs more than `min_count` times in the document, including frequent mispellings and emojis.

# %% [markdown]
# We can easily find the **similarity between two words** using word embeddings. Similarity is measured as the cosine between the two vectors and ranges between -1 and +1. The higher the cosine, the more similar two words are. As expected, the figures below show that *dog* is closer to *cat* than to *bird*, since variations of the phrase *dogs and cats* are common.

# %%
model.wv.vocab
# Out:
# {'help': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca8e0>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7f83f47cae80>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca760>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca430>,
#  'engaging': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca9a0>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x7f83f47cafd0>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7f83f47cafa0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f83f47cab20>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca6d0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f83f47cacd0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca160>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca1f0>,
#  'practice': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca0a0>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca190>,
#  'math': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca910>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca550>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca490>,
#  'classroom': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca340>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca4f0>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x7f83f47ca790>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f83f47caaf0>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x7f83f4328d30>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f83f4328cd0>,
#  'pencil': <gensim.models.keyedvectors.Vocab at 0x7f83f4328580>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x7f83f4328070>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f83f4328430>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce0a0>,
#  'remote': <gensim.models.keyedvectors.Vocab at 0x7f83f47ceaf0>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7f83f47cee50>,
#  'workbook': <gensim.models.keyedvectors.Vocab at 0x7f83f47ceeb0>,
#  'snack': <gensim.models.keyedvectors.Vocab at 0x7f83f47cec70>,
#  'remote_learning': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce190>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce100>,
#  'distance': <gensim.models.keyedvectors.Vocab at 0x7f83f47cecd0>,
#  'seat': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce4f0>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce2b0>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f83f47cedf0>,
#  'skill': <gensim.models.keyedvectors.Vocab at 0x7f83f47cef40>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce580>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce520>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce040>,
#  'distance_learning': <gensim.models.keyedvectors.Vocab at 0x7f83f47ced60>,
#  'virtual': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce2e0>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce550>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f83f47cee20>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce940>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7f83f47cee80>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7f83f47ceb80>,
#  'curriculum': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce250>,
#  'ipad': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce1c0>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce160>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce370>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x7f83f47ce4c0>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7f83f49fd430>,
#  'seating': <gensim.models.keyedvectors.Vocab at 0x7f83f49fd4f0>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x7f83f49fdd60>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f83f49fd2b0>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x7f83f49fd340>,
#  'interactive': <gensim.models.keyedvectors.Vocab at 0x7f83f49fd310>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7f83f49fddf0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f83f49fd610>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f83f49fdca0>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba2b0>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba370>,
#  'lesson': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba250>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7f83f48bad90>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f83f48badf0>,
#  'printer': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba220>,
#  'ink': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba130>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba160>,
#  'manipulative': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba100>,
#  'headphone': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba190>,
#  'enhance': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba640>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x7f83f48baa90>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba040>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba820>,
#  'literature': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba850>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba610>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba280>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba4f0>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba070>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba490>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x7f83f48bac10>,
#  'crayon': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba550>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba3d0>,
#  'chromebook': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba9a0>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x7f83f48baf70>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x7f83f48baa60>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba5b0>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f83f48bae50>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f83f48baaf0>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x7f83f48baac0>,
#  'creative': <gensim.models.keyedvectors.Vocab at 0x7f83f48baca0>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7f83f48bad60>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x7f83f48baf40>,
#  'equipment': <gensim.models.keyedvectors.Vocab at 0x7f83f48bafa0>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x7f83f48baeb0>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x7f83f48bae20>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba5e0>,
#  'literacy': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba7f0>,
#  'successful': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba670>,
#  'whiteboard': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba760>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x7f83f48ba730>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f83f45aefd0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f83f45aebe0>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae9d0>,
#  'resource': <gensim.models.keyedvectors.Vocab at 0x7f83f45aee20>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae370>,
#  'engage': <gensim.models.keyedvectors.Vocab at 0x7f83f45aedc0>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae220>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae8e0>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae4c0>,
#  'instrument': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae1c0>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae490>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae0d0>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x7f83f45aef40>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae760>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae700>,
#  'high_interest': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae5b0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae790>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae0a0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae250>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f83f45aea00>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae7c0>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae970>,
#  'tool': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae1f0>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae580>,
#  'storage': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae340>,
#  'pro': <gensim.models.keyedvectors.Vocab at 0x7f83f45aedf0>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x7f83f45aed00>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x7f83f45aeb80>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f83f45aec10>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae430>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f83f45aefa0>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x7f83f45aed90>,
#  'library': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae610>,
#  'sensory': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae9a0>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7f83f45aeeb0>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x7f83f45aed30>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f83f45aee50>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x7f83f45aeaf0>,
#  'stem': <gensim.models.keyedvectors.Vocab at 0x7f83f45aea60>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f83f45ae040>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4850>,
#  'school_year': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4e20>,
#  'emotional': <gensim.models.keyedvectors.Vocab at 0x7f83f49b42b0>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x7f83f49b49a0>,
#  'social_emotional': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4670>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f83f49b48b0>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x7f83f49b41f0>,
#  'explore': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4ac0>,
#  'marker': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4100>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4220>,
#  'magnetic': <gensim.models.keyedvectors.Vocab at 0x7f83f49b49d0>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x7f83f49b40d0>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7f83f49b48e0>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4040>,
#  'camera': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4e80>,
#  'document_camera': <gensim.models.keyedvectors.Vocab at 0x7f83f49b43d0>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x7f83f49b4130>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f83f49b43a0>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f83f55899a0>,
#  'laptop': <gensim.models.keyedvectors.Vocab at 0x7f83f5589fa0>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7f83f5589e20>,
#  'flexible': <gensim.models.keyedvectors.Vocab at 0x7f83f5589880>,
#  'flexible_seating': <gensim.models.keyedvectors.Vocab at 0x7f83f5589d60>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f83f5589bb0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f83f5589b20>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7f83f5589160>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f83f5589100>,
#  'pandemic': <gensim.models.keyedvectors.Vocab at 0x7f83f5589280>,
#  'sight': <gensim.models.keyedvectors.Vocab at 0x7f83f5589f10>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f83f5589220>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f83f55891c0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f83f5589730>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x7f83f5589670>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x7f83f5589d30>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x7f83f5589b80>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f83f5589520>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f83f55895e0>,
#  'classroom_library': <gensim.models.keyedvectors.Vocab at 0x7f83f55892b0>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7f83f5589820>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x7f83f55890d0>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x7f83f5589a90>,
#  'dry_erase': <gensim.models.keyedvectors.Vocab at 0x7f83f5589e80>,
#  'tablet': <gensim.models.keyedvectors.Vocab at 0x7f83f5589c70>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x7f83f5589af0>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x7f83f5589640>,
#  'organize': <gensim.models.keyedvectors.Vocab at 0x7f83f55893d0>,
#  'pen': <gensim.models.keyedvectors.Vocab at 0x7f83f55892e0>,
#  'journal': <gensim.models.keyedvectors.Vocab at 0x7f83f55894c0>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7f83f5589910>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x7f83f5589ca0>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f83f5589b50>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f83f55896a0>,
#  'reader': <gensim.models.keyedvectors.Vocab at 0x7f83f5589a00>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7f83f5589490>}

# %%
print(model.wv.similarity("book", "literacy"))
print(model.wv.similarity("chromebook", "technology"))
print(model.wv.similarity("music", "instrument"))
# Out:
# 0.9995235
# 0.99858797
# 0.99762845

# %% [markdown]
# In a similar vein, we can find the **words that are most similar to a target word**. The words with the closest embedding to *college* are for words associated with *getting* to college (e.g. resoureces, materials, skills)

# %%
model.wv.similar_by_word("literacy", topn=10)
# Out:
# [('book', 0.999523401260376),
#  ('math', 0.9995233416557312),
#  ('marker', 0.9994785785675049),
#  ('learn', 0.9994757175445557),
#  ('help', 0.9994710683822632),
#  ('card', 0.9994686245918274),
#  ('skill', 0.999454140663147),
#  ('need', 0.9994530081748962),
#  ('paper', 0.9994516372680664),
#  ('pencil', 0.9994442462921143)]

# %% [markdown]
# Interestingly, we can look for **words that are similar to a set of words and dissimilar to another set of words** at the same time. This allows us to look for analogies of the type *puppy is to dog as  ... is to cat*.

# %%
#model.wv.most_similar(positive=['puppy', 'cat'], negative=["dog"], topn=10)
model.wv.most_similar(positive=['book', 'computer'], negative=["literacy"], topn=10)
# Out:
# [('student', 0.9988638162612915),
#  ('board', 0.998816967010498),
#  ('classroom', 0.998805046081543),
#  ('help', 0.9987744092941284),
#  ('learn', 0.9987449049949646),
#  ('material', 0.9987318515777588),
#  ('sensory', 0.9987295269966125),
#  ('skill', 0.9987154006958008),
#  ('like', 0.9987146854400635),
#  ('seat', 0.9986968040466309)]

# %% [markdown]
# We can use embeddings to **explore the meaning of words**. The word *puppy* is very similar to *pup*, a diminutive of the word, and also similar to *kitten*, another young animal:

# %%
model.wv.most_similar(positive=["book"], topn=10)
# Out:
# [('help', 0.999796986579895),
#  ('student', 0.999778151512146),
#  ('learn', 0.9997513294219971),
#  ('pencil', 0.9997369050979614),
#  ('skill', 0.9997270107269287),
#  ('classroom', 0.9997210502624512),
#  ('card', 0.999707818031311),
#  ('board', 0.9996935129165649),
#  ('reading', 0.9996853470802307),
#  ('paper', 0.9996852874755859)]

# %% [markdown]
# We can get other details behind the **meaning of words** by looking at words that are similar to *puppy* but don't refer to a *dog*. In comments from `r/aww`, people commonly say that puppies are little, lovable and fuzzy.

# %%
model.wv.most_similar(positive=["skill"], negative=["reading"], topn=10)
# Out:
# [('fill', 0.012097954750061035),
#  ('manipulative', 0.011895358562469482),
#  ('organize', 0.009700179100036621),
#  ('prepare', 0.009436413645744324),
#  ('good', 0.00918019562959671),
#  ('sensory', 0.008832134306430817),
#  ('increase', 0.00865963101387024),
#  ('send', 0.00852898508310318),
#  ('whiteboard', 0.00821889191865921),
#  ('provide', 0.008058600127696991)]

# %% [markdown]
# Finally, use word embeddings to identify **the word in a list that is least similar to the others**:

# %%
#print(model.wv.doesnt_match("elephant cat cheese mouse".split()))
#print(model.wv.doesnt_match("sky bird sun stars".split()))
# Out:
# cat
# bird

# %% [markdown]
# ## Plotting embeddings

# %% [markdown]
# Word embeddings are high-dimensional vectors. In this example, our word embeddings have 100 dimensions. There is no hierarchy in the explanatory power of each dimension so we can't simply plot the first two or three dimensions and expect to see significant patterns.
#
# To plot embeddings with high dimensionality, we first need to map them to a dimensionality of 2. We do this with the popular [t-SNE](https://lvdmaaten.github.io/tsne/) method. T-SNE, short for **t-distributed Stochastic Neighbor Embedding**, helps us visualize high-dimensional data by mapping similar data to nearby points and dissimilar data to distance points in two-dimensional space.
#
# T-SNE is available in [Scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html). To run it, we just have to specify the number of dimensions we'd like to map the data to (`n_components`), and the similarity metric that t-SNE should use to compute the similarity between two data points (`metric`). We're going to map to 2 dimensions and use the cosine as our similarity metric. Additionally, we use PCA as an initialization method to remove some noise and speed up computation. The [Scikit-learn user guide](https://scikit-learn.org/stable/modules/manifold.html#t-sne) contains some additional tips for optimizing performance.
#
# Plotting all the embeddings in our vector space (all of the words in the vocabulary) would result in a very crowded figure. Therefore we'll focus on a subset of embeddings by selecting the 200 most similar words to a target word.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.manifold import TSNE

target_word = "book"
selected_words = [w[0] for w in model.wv.most_similar(positive=[target_word], topn=100)]
embeddings = [model.wv[w] for w in selected_words]

mapped_embeddings = TSNE(n_components=2, metric='cosine', init='pca').fit_transform(embeddings)

# %%
plt.figure(figsize=(30,30))
x = mapped_embeddings[:,0]
y = mapped_embeddings[:,1]
plt.scatter(x, y)

for i, txt in enumerate(selected_words):
    plt.annotate(txt, (x[i], y[i]), size=25)

# %% [markdown]
# ## Clustering embeddings

# %% [markdown]
# Finally, we're going to cluster our embeddings. We'll use agglomerative clustering, a bottom-up clustering method that iteratively takes together the two most similar clusters (or embeddings) in the data.

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize

vocab = list(model.wv.vocab)
vectors = [model.wv[w] for w in vocab]
vectors_norm = normalize(vectors)

clusterer = AgglomerativeClustering(n_clusters=50)
clusters = clusterer.fit_predict(vectors_norm)

# %%
cluster_dictionary = {}
for cluster, word in zip(clusters, vocab): 
    if cluster not in cluster_dictionary:
        cluster_dictionary[cluster] = []
    cluster_dictionary[cluster].append(word)

# %%
for x in cluster_dictionary:
    if "opportunity" in cluster_dictionary[x]:
        print(cluster_dictionary[x])
# Out:
# ['help', 'student', 'reading', 'digital', 'program', 'game', 'use', 'way', 'home', 'practice', 'learn', 'math', 'comfortable', 'classroom', 'space', 'school', 'supply', 'need', 'pencil', 'learning', 'hand', 'material', 'remote', 'social', 'distance', 'book', 'skill', 'play', 'card', 'continue', 'teacher', 'curriculum', 'language', 'allow', 'seating', 'option', 'work', 'provide', 'time', 'lesson', 'video', 'printer', 'enhance', 'love', 'class', 'art', 'paper', 'create', 'technology', 'activity', 'read', 'project', 'education', 'write', 'word', 'access', 'resource', 'set', 'high', 'interest', 'high_interest', 'able', 'tool', 'group', 'board', 'sensory', 'letter', 'variety', 'stem', 'science', 'explore', 'marker', 'fun', 'opportunity', 'document', 'camera', 'like', 'experience', 'online', 'flexible', 'gift', 'different', 'dry', 'erase']

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Word embeddings are one of the most exciting trends on Natural Language Processing since the 2000s. They allow us to model the meaning and usage of a word, and discover words that behave similarly. This is crucial for the generalization capacity of many machine learning models. Moving from raw strings to embeddings allows them to generalize across words that have a similar meaning, and discover patterns that had previously escaped them.

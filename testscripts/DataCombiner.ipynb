# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import clear_output

from datetime import datetime, timedelta, date #for time duration calculations
from dateutil.parser import parse #for fuzzy finding year

import pickle #for saving output files, pickles
from sys import stdout
import time #for time.sleep function to delay calls
from tqdm import tqdm #for updating loop
#from os import listdir
#from os.path import isfile, join
import glob #pattern matching and expansion.

## Python packages - you may have to pip install sqlalchemy, sqlalchemy_utils, and psycopg2.
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy.sql import table, column, select, update, insert
import psycopg2
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

import pandas as pd

#In Python: Define your username and password used above. I've defined the database name (we're 
#using a dataset on births, so I call it birth_db). 
dbname = 'donors_db'
username = 'russell'
pswd = 'bradypodion'

# %%
## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print(engine.url)
# Replace localhost with IP address if accessing a remote server
# Out:
# postgresql://russell:bradypodion@localhost/donors_db
# postgresql://russell:bradypodion@localhost/donors_db

# %%
## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
print(engine.url)
# Out:
# True
# postgresql://russell:bradypodion@localhost/donors_db

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
# connect:
con = None
con = psycopg2.connect(database = dbname, user = username, host='localhost', password=pswd)

# %%
#loop through states, merge from historical and scraped data
#

totalrows=0

state_specific_obs={}

for stateval in states:

    ###########################################################
    ### query: from historical data
    hist_query = """
    SELECT * FROM hist_projects WHERE school_state='"""+stateval+"';\n"


    hist_state = pd.read_sql_query(hist_query,con)
    orig_hist_rows = len(hist_state.index)
    hist_state = hist_state.drop_duplicates(keep='first')
    dedup_hist_rows = len(hist_state.index)

    ############################################### 
    ### query: from scraped data
    scrape_query = """
    SELECT * FROM scraped_project_metrics WHERE state='"""+stateval+"';\n"

    scrape_state = pd.read_sql_query(scrape_query,con)
    orig_scrape_rows = len(scrape_state.index)
    scrape_state = scrape_state.drop_duplicates(keep='first')
    dedup_scrape_rows = len(scrape_state.index)
    ###############################################################
    print("For "+stateval+"\nHistorical Raw Obs = "+str(orig_hist_rows)+"\nDeDup Obs = "+str(dedup_hist_rows))
    print("Scraped Raw Obs = "+str(orig_scrape_rows)+"\nDeDup Scraped Obs = "+str(dedup_scrape_rows))

    new_state = pd.merge(scrape_state,hist_state,left_on=['latitude','longitude','ffyear','numDonors','expirationDate'],right_on = ['school_latitude', 'school_longitude','year_completed','num_donors','calendar_expired'])
    new_state = new_state.drop_duplicates(subset='id',keep='first')
    merge_rows=len(new_state.index)
    
    state_specific_obs[stateval] = merge_rows
    #state_specific_obs.update=({stateval:merge_rows})
    
    print(stateval+': total merge obs = '+str(merge_rows))
    totalrows += merge_rows
    
    new_state.to_sql('merge_projects', engine, if_exists='append')
print("Total merge obs = "+str(totalrows))
# Out:
# For AL
# Historical Raw Obs = 14590
# DeDup Obs = 14590
# Scraped Raw Obs = 26470
# DeDup Scraped Obs = 26466
# AL: total merge obs = 1269
# For AK
# Historical Raw Obs = 3155
# DeDup Obs = 3155
# Scraped Raw Obs = 8223
# DeDup Scraped Obs = 8223
# AK: total merge obs = 548
# For AZ
# Historical Raw Obs = 23622
# DeDup Obs = 23622
# Scraped Raw Obs = 36633
# DeDup Scraped Obs = 36633
# AZ: total merge obs = 1541
# For AR
# Historical Raw Obs = 12588
# DeDup Obs = 12588
# Scraped Raw Obs = 26701
# DeDup Scraped Obs = 26700
# AR: total merge obs = 1854
# For CA
# Historical Raw Obs = 243799
# DeDup Obs = 243799
# Scraped Raw Obs = 139904
# DeDup Scraped Obs = 139904
# CA: total merge obs = 6547
# For CO
# Historical Raw Obs = 14631
# DeDup Obs = 14631
# Scraped Raw Obs = 22131
# DeDup Scraped Obs = 22130
# CO: total merge obs = 876
# For CT
# Historical Raw Obs = 17564
# DeDup Obs = 17564
# Scraped Raw Obs = 27834
# DeDup Scraped Obs = 27834
# CT: total merge obs = 1401
# For DC
# Historical Raw Obs = 13648
# DeDup Obs = 13648
# Scraped Raw Obs = 20331
# DeDup Scraped Obs = 20331
# DC: total merge obs = 1063
# For DE
# Historical Raw Obs = 3406
# DeDup Obs = 3406
# Scraped Raw Obs = 7516
# DeDup Scraped Obs = 7516
# DE: total merge obs = 397
# For FL
# Historical Raw Obs = 66420
# DeDup Obs = 66420
# Scraped Raw Obs = 72759
# DeDup Scraped Obs = 72759
# FL: total merge obs = 3471
# For GA
# Historical Raw Obs = 36957
# DeDup Obs = 36957
# Scraped Raw Obs = 53894
# DeDup Scraped Obs = 53894
# GA: total merge obs = 2474
# For HI
# Historical Raw Obs = 6253
# DeDup Obs = 6253
# Scraped Raw Obs = 16620
# DeDup Scraped Obs = 16620
# HI: total merge obs = 1223
# For ID
# Historical Raw Obs = 5488
# DeDup Obs = 5488
# Scraped Raw Obs = 13901
# DeDup Scraped Obs = 13901
# ID: total merge obs = 713
# For IL
# Historical Raw Obs = 83250
# DeDup Obs = 83250
# Scraped Raw Obs = 68405
# DeDup Scraped Obs = 68405
# IL: total merge obs = 3963
# For IN
# Historical Raw Obs = 37873
# DeDup Obs = 37873
# Scraped Raw Obs = 43941
# DeDup Scraped Obs = 43941
# IN: total merge obs = 2065
# For IA
# Historical Raw Obs = 7350
# DeDup Obs = 7350
# Scraped Raw Obs = 12490
# DeDup Scraped Obs = 12490
# IA: total merge obs = 1033
# For KS
# Historical Raw Obs = 6549
# DeDup Obs = 6549
# Scraped Raw Obs = 15555
# DeDup Scraped Obs = 15555
# KS: total merge obs = 875
# For KY
# Historical Raw Obs = 10240
# DeDup Obs = 10240
# Scraped Raw Obs = 21541
# DeDup Scraped Obs = 21541
# KY: total merge obs = 1182
# For LA
# Historical Raw Obs = 27030
# DeDup Obs = 27030
# Scraped Raw Obs = 37835
# DeDup Scraped Obs = 37835
# LA: total merge obs = 2453
# For ME
# Historical Raw Obs = 7154
# DeDup Obs = 7154
# Scraped Raw Obs = 13471
# DeDup Scraped Obs = 13462
# ME: total merge obs = 666
# For MD
# Historical Raw Obs = 20368
# DeDup Obs = 20368
# Scraped Raw Obs = 30713
# DeDup Scraped Obs = 30713
# MD: total merge obs = 1657
# For MA
# Historical Raw Obs = 23211
# DeDup Obs = 23211
# Scraped Raw Obs = 34036
# DeDup Scraped Obs = 34036
# MA: total merge obs = 1292
# For MI
# Historical Raw Obs = 29673
# DeDup Obs = 29673
# Scraped Raw Obs = 41357
# DeDup Scraped Obs = 41357
# MI: total merge obs = 1823
# For MN
# Historical Raw Obs = 10458
# DeDup Obs = 10458
# Scraped Raw Obs = 25458
# DeDup Scraped Obs = 25458
# MN: total merge obs = 750
# For MS
# Historical Raw Obs = 15650
# DeDup Obs = 15650
# Scraped Raw Obs = 26481
# DeDup Scraped Obs = 26481
# MS: total merge obs = 1168
# For MO
# Historical Raw Obs = 26325
# DeDup Obs = 26325
# Scraped Raw Obs = 51724
# DeDup Scraped Obs = 51724
# MO: total merge obs = 2431
# For MT
# Historical Raw Obs = 2127
# DeDup Obs = 2127
# Scraped Raw Obs = 7503
# DeDup Scraped Obs = 7503
# MT: total merge obs = 258
# For NE
# Historical Raw Obs = 3410
# DeDup Obs = 3410
# Scraped Raw Obs = 5458
# DeDup Scraped Obs = 5458
# NE: total merge obs = 431
# For NV
# Historical Raw Obs = 17861
# DeDup Obs = 17861
# Scraped Raw Obs = 23043
# DeDup Scraped Obs = 23043
# NV: total merge obs = 1549
# For NH
# Historical Raw Obs = 3288
# DeDup Obs = 3288
# Scraped Raw Obs = 6667
# DeDup Scraped Obs = 6667
# NH: total merge obs = 255
# For NJ
# Historical Raw Obs = 22940
# DeDup Obs = 22940
# Scraped Raw Obs = 35370
# DeDup Scraped Obs = 35366
# NJ: total merge obs = 1655
# For NM
# Historical Raw Obs = 5774
# DeDup Obs = 5774
# Scraped Raw Obs = 18386
# DeDup Scraped Obs = 18386
# NM: total merge obs = 784
# For NY
# Historical Raw Obs = 149420
# DeDup Obs = 149420
# Scraped Raw Obs = 86894
# DeDup Scraped Obs = 86894
# NY: total merge obs = 5556
# For NC
# Historical Raw Obs = 90404
# DeDup Obs = 90404
# Scraped Raw Obs = 74820
# DeDup Scraped Obs = 74820
# NC: total merge obs = 3455
# For ND
# Historical Raw Obs = 1178
# DeDup Obs = 1178
# Scraped Raw Obs = 3603
# DeDup Scraped Obs = 3603
# ND: total merge obs = 170
# For OH
# Historical Raw Obs = 19218
# DeDup Obs = 19218
# Scraped Raw Obs = 37764
# DeDup Scraped Obs = 37764
# OH: total merge obs = 1257
# For OK
# Historical Raw Obs = 33248
# DeDup Obs = 33248
# Scraped Raw Obs = 42455
# DeDup Scraped Obs = 42455
# OK: total merge obs = 2360
# For OR
# Historical Raw Obs = 15629
# DeDup Obs = 15629
# Scraped Raw Obs = 18394
# DeDup Scraped Obs = 18394
# OR: total merge obs = 1239
# For PA
# Historical Raw Obs = 33476
# DeDup Obs = 33476
# Scraped Raw Obs = 50475
# DeDup Scraped Obs = 50475
# PA: total merge obs = 2137
# For RI
# Historical Raw Obs = 4295
# DeDup Obs = 4295
# Scraped Raw Obs = 8334
# DeDup Scraped Obs = 8334
# RI: total merge obs = 538
# For SC
# Historical Raw Obs = 45309
# DeDup Obs = 45309
# Scraped Raw Obs = 59598
# DeDup Scraped Obs = 59598
# SC: total merge obs = 2959
# For SD
# Historical Raw Obs = 2345
# DeDup Obs = 2345
# Scraped Raw Obs = 9399
# DeDup Scraped Obs = 9399
# SD: total merge obs = 334
# For TN
# Historical Raw Obs = 28064
# DeDup Obs = 28064
# Scraped Raw Obs = 29935
# DeDup Scraped Obs = 29935
# TN: total merge obs = 1657
# For TX
# Historical Raw Obs = 87241
# DeDup Obs = 87241
# Scraped Raw Obs = 80629
# DeDup Scraped Obs = 80629
# TX: total merge obs = 3333
# For UT
# Historical Raw Obs = 19208
# DeDup Obs = 19208
# Scraped Raw Obs = 24411
# DeDup Scraped Obs = 24411
# UT: total merge obs = 1895
# For VT
# Historical Raw Obs = 1214
# DeDup Obs = 1214
# Scraped Raw Obs = 2968
# DeDup Scraped Obs = 2968
# VT: total merge obs = 121
# For VA
# Historical Raw Obs = 24695
# DeDup Obs = 24695
# Scraped Raw Obs = 39061
# DeDup Scraped Obs = 39061
# VA: total merge obs = 1439
# For WA
# Historical Raw Obs = 25103
# DeDup Obs = 25103
# Scraped Raw Obs = 33888
# DeDup Scraped Obs = 33888
# WA: total merge obs = 1951
# For WV
# Historical Raw Obs = 5476
# DeDup Obs = 5476
# Scraped Raw Obs = 15766
# DeDup Scraped Obs = 15766
# WV: total merge obs = 572
# For WI
# Historical Raw Obs = 16191
# DeDup Obs = 16191
# Scraped Raw Obs = 27084
# DeDup Scraped Obs = 27084
# WI: total merge obs = 1314
# For WY
# Historical Raw Obs = 797
# DeDup Obs = 797
# Scraped Raw Obs = 4372
# DeDup Scraped Obs = 4372
# WY: total merge obs = 162
# Total merge obs = 82116

# %%
### Close communication with the database
con.close()

# %%
################# this will list objects in the working memory equivalent, sorted by size, descending


import sys

# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)
# Out:
# [('states', 464),
#  ('date', 416),
#  ('timedelta', 416),
#  ('con', 304),
#  ('clear_output', 136),
#  ('column', 136),
#  ('create_database', 136),
#  ('create_engine', 136),
#  ('database_exists', 136),
#  ('insert', 136),
#  ('parse', 136),
#  ('table', 136),
#  ('update', 136),
#  ('scrape_query', 106),
#  ('hist_query', 103),
#  ('sql_query', 103),
#  ('np', 72),
#  ('pd', 72),
#  ('plt', 72),
#  ('sns', 72),
#  ('pswd', 60),
#  ('dbname', 58),
#  ('username', 56),
#  ('stateval', 51),
#  ('engine', 48),
#  ('stdout', 48),
#  ('dedup_hist_rows', 28),
#  ('dedup_scrape_rows', 28),
#  ('orig_hist_rows', 28),
#  ('orig_scrape_rows', 28),
#  ('ISOLATION_LEVEL_AUTOCOMMIT', 24)]
